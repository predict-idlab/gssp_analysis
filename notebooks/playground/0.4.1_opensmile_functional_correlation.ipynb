# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path
from typing import List, Optional

import pandas as pd
from IPython.display import display
from tqdm.auto import tqdm
from scipy.io import wavfile
import numpy as np
import torchaudio
import noisereduce

sys.path.append("..")
# opensmile
import opensmile

from sgs_utils.path_conf import (
    loc_data_dir,
    interim_speech_data_dir,
    speech_data_session_dir,
)
import seaborn as sns

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
# Load the session data and only parse the valid sessions
df_session = pd.read_parquet(loc_data_dir.joinpath("df_session_tot_cleaned.parquet"))
print(df_session.shape[0])
# Out:
# 3257

# %%
display((df_session.wav_duration_s > 15).value_counts())
wav_paths: List[Path] = (
    df_session[(df_session.wav_duration_s > 15)]
    .apply(
        lambda row: list(
            speech_data_session_dir.glob(
                f"*{row.ID}/{row.DB}/{row.pic_name}__{row.time_str}.wav"
            )
        )[0],
        axis=1
    )
    .values
)
# Out:
# True     3197
# False      60
# Name: wav_duration_s, dtype: int64

# %% [markdown]
# # Extracting features

# %% [markdown]
# useful links:
# * [opensmile config folder](https://github.com/audeering/opensmile/tree/v3.0.0/config)
# * difference between GeMAPS versions [here](https://github.com/audeering/opensmile/blob/v3.0.0/config/gemaps/CHANGES.txt')
#
# **note**: `eGeMAPS` is an _extended_ version of the GeMAPS
#
# feature-level`
# * `Functionals`: global segment based features (1 feature per segment)
# * `LowLevelDescriptor`: sliding window features (1 feature per window)

# %%
# define the feature extraction configs
func_gemaps = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.Functionals,
)

func_compare = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

func_emobase = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
from functional import seq

seq(func_gemaps.feature_names).filter(
    lambda x: any(substr in x.lower() for substr in ["jitter", "shimmer"])
).to_list()
# Out:
# ['jitterLocal_sma3nz_amean',
#  'jitterLocal_sma3nz_stddevNorm',
#  'shimmerLocaldB_sma3nz_amean',
#  'shimmerLocaldB_sma3nz_stddevNorm']

# %%
from multiprocessing import Pool
import traceback
from typing import Tuple

# %% [markdown]
# ### Whole file duration

# %%
def _extract_parse_smile_df(s: opensmile.Smile, wav_file_path: Path) -> pd.DataFrame:
    # Extract the features on
    # * the WAV file
    # * The normalized signal
    # * the 16_000 Hz resampled signal
    # * the processed 16_000 Hz signal

    df_feat_list = []

    try:
        arr, fs = torchaudio.load(wav_file_path, normalize=True)
        assert arr.size(1) / fs > 10, "File too short"
    except:
        return pd.DataFrame()

    arr_16k = (
        torchaudio.functional.resample(arr, orig_freq=fs, new_freq=16_000)
        .numpy()
        .ravel()
    )
    arr = arr.numpy().ravel()

    # 1. Parse the WAV file
    df_feat = s.process_file(file=wav_file_path)
    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype("str")
    df_feat["pic_name"] = wav_file_path.name.split("__")[0]
    df_feat["time_str"] = wav_file_path.name.split("__")[1].split(".")[0]
    df_feat["DB"] = wav_file_path.parent.name
    df_feat["ID"] = wav_file_path.parent.parent.name.split("__")[-1]
    df_feat["input_type"] = "wav"
    df_feat_list.append(df_feat)

    # 2. Parse the signal
    df_feat = s.process_signal(arr, sampling_rate=fs, file=wav_file_path)
    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype("str")
    df_feat["pic_name"] = wav_file_path.name.split("__")[0]
    df_feat["time_str"] = wav_file_path.name.split("__")[1].split(".")[0]
    df_feat["DB"] = wav_file_path.parent.name
    df_feat["ID"] = wav_file_path.parent.parent.name.split("__")[-1]
    df_feat["input_type"] = "arr"
    df_feat_list.append(df_feat)

    # 3. Parse the 16KHz signal
    df_feat = s.process_signal(arr_16k, sampling_rate=16_000, file=wav_file_path)
    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype("str")
    df_feat["pic_name"] = wav_file_path.name.split("__")[0]
    df_feat["time_str"] = wav_file_path.name.split("__")[1].split(".")[0]
    df_feat["DB"] = wav_file_path.parent.name
    df_feat["ID"] = wav_file_path.parent.parent.name.split("__")[-1]
    df_feat["input_type"] = "arr_16k"
    df_feat_list.append(df_feat)

    # 4. Parse the processed 16KHz signal
    arr_16k_nr_s = noisereduce.reduce_noise(
        arr_16k, sr=16_000, prop_decrease=0.85, n_fft=256, n_std_thresh_stationary=0.75
    )
    df_feat = s.process_signal(arr_16k_nr_s, sampling_rate=16_000, file=wav_file_path)
    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype("str")
    df_feat["pic_name"] = wav_file_path.name.split("__")[0]
    df_feat["time_str"] = wav_file_path.name.split("__")[1].split(".")[0]
    df_feat["DB"] = wav_file_path.parent.name
    df_feat["ID"] = wav_file_path.parent.parent.name.split("__")[-1]
    df_feat["input_type"] = "arr_16k_nr_s"
    df_feat_list.append(df_feat)

    return pd.concat(df_feat_list, axis=0, ignore_index=True)


def _extract_opensmile_f(file: Path) -> Tuple[pd.DataFrame, ...]:
    # calculate the global utterance features
    return (
        _extract_parse_smile_df(func_gemaps, wav_file_path=file),
        # _extract_parse_smile_df(func_compare, wav_file_path=file),
        # _extract_parse_smile_df(func_emobase, wav_file_path=file),
    )


out = None
with Pool(processes=6) as pool:
    # Wav files
    wav_files = wav_paths 
    wav_files = wav_files[::30]

    results = pool.imap_unordered(_extract_opensmile_f, wav_files)
    results = tqdm(results, total=len(wav_files))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()


def _parse_concat_df(df_conc: pd.DataFrame) -> pd.DataFrame:
    df_conc["DB"] = df_conc["DB"].astype("category")
    df_conc["pic_name"] = df_conc["pic_name"].astype("category")
    df_conc["ID"] = df_conc["ID"].astype("category")
    return df_conc


df_gemaps_func = _parse_concat_df(pd.concat([o[0] for o in out], ignore_index=True))
# df_compare_func = _parse_concat_df(pd.concat([o[1] for o in out], ignore_index=True))
# df_emobase_func = _parse_concat_df(pd.concat([o[2] for o in out], ignore_index=True))

del (
    out,
    _extract_opensmile_f,
    _parse_concat_df,
    _extract_parse_smile_df,
)
# Out:
#   0%|          | 0/107 [00:00<?, ?it/s]

# %%
for df in [df_gemaps_func]: # df_emobase_func]:
    input_types = df["input_type"].unique()
    reference_input_type = "wav"

    reference = df[df.input_type == reference_input_type].set_index("file")
    series_list = []
    for input_type in set(input_types).difference({reference_input_type}):
        input = df[df.input_type == input_type].set_index("file")
        series_list.append(
            reference.corrwith(input).rename(
                f"corr_{reference_input_type}_{input_type}"
            )
        )

    cmap = sns.color_palette("coolwarm", as_cmap=True)
    display(
        pd.concat(series_list, axis=1)
        .round(3)
        .style.background_gradient(cmap=cmap, vmin=-1, vmax=1)
    )
# Out:
# <style type="text/css">
# #T_f2a0f_row0_col0, #T_f2a0f_row1_col0, #T_f2a0f_row2_col0, #T_f2a0f_row3_col0, #T_f2a0f_row4_col0, #T_f2a0f_row5_col0, #T_f2a0f_row6_col0, #T_f2a0f_row7_col0, #T_f2a0f_row8_col0, #T_f2a0f_row9_col0, #T_f2a0f_row10_col0, #T_f2a0f_row10_col2, #T_f2a0f_row11_col0, #T_f2a0f_row11_col2, #T_f2a0f_row12_col0, #T_f2a0f_row12_col1, #T_f2a0f_row12_col2, #T_f2a0f_row13_col0, #T_f2a0f_row13_col2, #T_f2a0f_row14_col0, #T_f2a0f_row14_col2, #T_f2a0f_row15_col0, #T_f2a0f_row16_col0, #T_f2a0f_row17_col0, #T_f2a0f_row18_col0, #T_f2a0f_row19_col0, #T_f2a0f_row20_col0, #T_f2a0f_row21_col0, #T_f2a0f_row22_col0, #T_f2a0f_row23_col0, #T_f2a0f_row24_col0, #T_f2a0f_row25_col0, #T_f2a0f_row26_col0, #T_f2a0f_row27_col0, #T_f2a0f_row28_col0, #T_f2a0f_row29_col0, #T_f2a0f_row30_col0, #T_f2a0f_row31_col0, #T_f2a0f_row32_col0, #T_f2a0f_row33_col0, #T_f2a0f_row34_col0, #T_f2a0f_row35_col0, #T_f2a0f_row36_col0, #T_f2a0f_row37_col0, #T_f2a0f_row38_col0, #T_f2a0f_row39_col0, #T_f2a0f_row40_col0, #T_f2a0f_row41_col0, #T_f2a0f_row42_col0, #T_f2a0f_row43_col0, #T_f2a0f_row44_col0, #T_f2a0f_row45_col0, #T_f2a0f_row46_col0, #T_f2a0f_row47_col0, #T_f2a0f_row48_col0, #T_f2a0f_row49_col0, #T_f2a0f_row50_col0, #T_f2a0f_row51_col0, #T_f2a0f_row52_col0, #T_f2a0f_row53_col0, #T_f2a0f_row54_col0, #T_f2a0f_row55_col0, #T_f2a0f_row56_col0, #T_f2a0f_row57_col0, #T_f2a0f_row58_col0, #T_f2a0f_row59_col0, #T_f2a0f_row60_col0, #T_f2a0f_row61_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2a0f_row0_col1, #T_f2a0f_row3_col2, #T_f2a0f_row19_col2, #T_f2a0f_row23_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_f2a0f_row0_col2, #T_f2a0f_row56_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_f2a0f_row1_col1, #T_f2a0f_row2_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_f2a0f_row1_col2, #T_f2a0f_row31_col2, #T_f2a0f_row35_col2, #T_f2a0f_row39_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_f2a0f_row2_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_f2a0f_row3_col1, #T_f2a0f_row33_col1, #T_f2a0f_row38_col1, #T_f2a0f_row42_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_f2a0f_row4_col1, #T_f2a0f_row58_col1, #T_f2a0f_row60_col1 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_f2a0f_row4_col2, #T_f2a0f_row26_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_f2a0f_row5_col1, #T_f2a0f_row6_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_f2a0f_row5_col2 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_f2a0f_row6_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_f2a0f_row7_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_f2a0f_row7_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_f2a0f_row8_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f2a0f_row8_col2, #T_f2a0f_row29_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_f2a0f_row9_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f2a0f_row9_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f2a0f_row10_col1, #T_f2a0f_row11_col1, #T_f2a0f_row16_col1, #T_f2a0f_row16_col2, #T_f2a0f_row18_col2, #T_f2a0f_row48_col2, #T_f2a0f_row52_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_f2a0f_row13_col1, #T_f2a0f_row15_col1, #T_f2a0f_row15_col2, #T_f2a0f_row54_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_f2a0f_row14_col1, #T_f2a0f_row52_col2, #T_f2a0f_row53_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_f2a0f_row17_col1, #T_f2a0f_row19_col1, #T_f2a0f_row46_col1, #T_f2a0f_row47_col2, #T_f2a0f_row61_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_f2a0f_row17_col2, #T_f2a0f_row24_col1 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_f2a0f_row18_col1, #T_f2a0f_row46_col2, #T_f2a0f_row53_col1, #T_f2a0f_row54_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_f2a0f_row20_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_f2a0f_row20_col2, #T_f2a0f_row37_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_f2a0f_row21_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_f2a0f_row21_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_f2a0f_row22_col1, #T_f2a0f_row30_col1, #T_f2a0f_row38_col2, #T_f2a0f_row42_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_f2a0f_row22_col2, #T_f2a0f_row35_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_f2a0f_row23_col2, #T_f2a0f_row44_col1, #T_f2a0f_row48_col1, #T_f2a0f_row61_col1 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_f2a0f_row24_col2, #T_f2a0f_row28_col1, #T_f2a0f_row45_col1, #T_f2a0f_row50_col2 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_f2a0f_row25_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_f2a0f_row25_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f2a0f_row26_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_f2a0f_row27_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f2a0f_row27_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f2a0f_row28_col2, #T_f2a0f_row50_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_f2a0f_row29_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f2a0f_row30_col2, #T_f2a0f_row34_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_f2a0f_row31_col1, #T_f2a0f_row33_col2, #T_f2a0f_row36_col1, #T_f2a0f_row41_col2, #T_f2a0f_row55_col2, #T_f2a0f_row59_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_f2a0f_row32_col1, #T_f2a0f_row41_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_f2a0f_row32_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_f2a0f_row34_col2, #T_f2a0f_row37_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_f2a0f_row36_col2, #T_f2a0f_row58_col2, #T_f2a0f_row59_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_f2a0f_row39_col2, #T_f2a0f_row43_col2, #T_f2a0f_row47_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_f2a0f_row40_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f2a0f_row40_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_f2a0f_row43_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_f2a0f_row44_col2, #T_f2a0f_row56_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_f2a0f_row45_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f2a0f_row49_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f2a0f_row49_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f2a0f_row51_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f2a0f_row51_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f2a0f_row55_col1 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_f2a0f_row57_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_f2a0f_row57_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_f2a0f_row60_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2a0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2a0f_level0_col0" class="col_heading level0 col0" >corr_wav_arr</th>
#       <th id="T_f2a0f_level0_col1" class="col_heading level0 col1" >corr_wav_arr_16k_nr_s</th>
#       <th id="T_f2a0f_level0_col2" class="col_heading level0 col2" >corr_wav_arr_16k</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2a0f_level0_row0" class="row_heading level0 row0" >F0semitoneFrom27.5Hz_sma3nz_amean</th>
#       <td id="T_f2a0f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f2a0f_row0_col1" class="data row0 col1" >0.871000</td>
#       <td id="T_f2a0f_row0_col2" class="data row0 col2" >0.889000</td>
#     </tr>
#     <tr>
#       <th id="T_f2a0f_level0_row1" class="row_heading level0 row1" >F0semitoneFrom27.5Hz_sma3nz_stddevNorm</th>
#       <td id="T_f2a0f_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_f2a0f_row1_col1" class="data row1 col1" >0.696000</td>
#       <td id="T_f2a0f_row1_col2" class="data row1 col2" >0.842000</td>
#     </tr>
#     <tr>
#       <th id="T_f2a0f_level0_row2" class="row_heading level0 ro
