# %% [markdown]
# # Speech Feature Extraction using OpenSMILE (GeMapsv01b + ComParE config)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path
from typing import List, Optional

import pandas as pd
from IPython.display import display
from tqdm.auto import tqdm
from scipy.io import wavfile

sys.path.append("..")
# opensmile
import opensmile

from sgs_utils.path_conf import loc_data_dir, speech_data_session_dir

# %% [markdown]
# # Extracting features

# %% [markdown]
# useful links:
# * [opensmile config folder](https://github.com/audeering/opensmile/tree/v3.0.0/config)
# * difference between GeMAPS versions [here](https://github.com/audeering/opensmile/blob/v3.0.0/config/gemaps/CHANGES.txt')
#
# **note**: `eGeMAPS` is an _extended_ version of the GeMAPS
#
# feature-level`
# * `Functionals`: global segment based features (1 feature per segment)
# * `LowLevelDescriptor`: sliding window features (1 feature per window)

# %%
df_session = pd.read_parquet(loc_data_dir.joinpath("df_session_tot.parquet"))

# %%
# define the feature extraction configs
func_gemaps = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.Functionals,
)

lld_gemaps = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# we will use the ComParE LLD to calculate frequency-based features on `F0final_sma`
lld_compare = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# %%
from multiprocessing import Pool
import traceback
from typing import Tuple

# %% [markdown]
# ### Whole file duration

# %%
def _extract_parse_smile_df(s: opensmile.Smile, f: Path) -> pd.DataFrame:
    df_feat = s.process_file(f)
    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype("str")

    # df_feat["fileName"] = f.name
    df_feat["pic_name"] = f.name.split("__")[0]
    df_feat["time_str"] = f.name.split("__")[1].split('.')[0]
    df_feat["DB"] = f.parent.name
    df_feat["ID"] = f.parent.parent.name.split('__')[-1]
    return df_feat

def _extract_opensmile_f(file: Path) -> Tuple[pd.DataFrame, ...]:
    # calculate the global utterance features
    return (
        _extract_parse_smile_df(func_gemaps, f=file),
        _extract_parse_smile_df(lld_gemaps, f=file),
        _extract_parse_smile_df(lld_compare, f=file),
    )

out = None
with Pool(processes=8) as pool:
    wav_files = list(speech_data_session_dir.glob("*/*/*.wav"))
    results = pool.imap_unordered(_extract_opensmile_f, wav_files)
    results = tqdm(results, total=len(wav_files))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()

def _parse_concat_df(df_conc: pd.DataFrame) -> pd.DataFrame:
    df_conc["DB"] = df_conc["DB"].astype("category")
    df_conc["pic_name"] = df_conc["pic_name"].astype("category")
    df_conc["ID"] = df_conc["ID"].astype("category")
    return df_conc


df_gemaps_func = _parse_concat_df(pd.concat([o[0] for o in out], ignore_index=True))
df_gemaps_lld = _parse_concat_df(pd.concat([o[1] for o in out], ignore_index=True))
df_compare_lld = _parse_concat_df(pd.concat([o[2] for o in out], ignore_index=True))

del (
    out,
    _extract_opensmile_f,
    _parse_concat_df,
    _extract_parse_smile_df,
)
# Out:
#   3%|▎         | 113/3260 [02:11<48:31,  1.08it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#   4%|▎         | 115/3260 [02:12<37:03,  1.41it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#   4%|▎         | 116/3260 [02:12<27:49,  1.88it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#   6%|▋         | 210/3260 [04:09<47:43,  1.07it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#   7%|▋         | 218/3260 [04:19<52:53,  1.04s/it]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  10%|█         | 335/3260 [05:57<39:21,  1.24it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  18%|█▊        | 589/3260 [10:16<1:24:03,  1.89s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  18%|█▊        | 593/3260 [10:20<57:17,  1.29s/it]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  21%|██        | 674/3260 [11:08<14:12,  3.03it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  22%|██▏       | 706/3260 [11:36<33:06,  1.29it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  22%|██▏       | 733/3260 [12:25<1:05:43,  1.56s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  23%|██▎       | 741/3260 [12:40<1:17:09,  1.84s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  23%|██▎       | 742/3260 [12:40<55:53,  1.33s/it]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  24%|██▎       | 773/3260 [13:03<34:39,  1.20it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  25%|██▍       | 800/3260 [13:22<28:21,  1.45it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  28%|██▊       | 925/3260 [15:06<27:34,  1.41it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  47%|████▋     | 1520/3260 [24:45<17:03,  1.70it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  47%|████▋     | 1538/3260 [24:52<12:47,  2.24it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  47%|████▋     | 1541/3260 [24:53<08:49,  3.24it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  47%|████▋     | 1545/3260 [24:55<14:52,  1.92it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  48%|████▊     | 1551/3260 [24:57<08:46,  3.25it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  68%|██████▊   | 2227/3260 [35:24<06:53,  2.50it/s]  /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  69%|██████▊   | 2234/3260 [35:34<36:25,  2.13s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  69%|██████▉   | 2246/3260 [35:53<46:22,  2.74s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  82%|████████▏ | 2682/3260 [41:01<07:29,  1.28it/s]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
#  98%|█████████▊| 3210/3260 [49:51<00:55,  1.11s/it]/home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# /home/jonas/.cache/pypoetry/virtualenvs/semi-guided-speech-27YL4uf1-py3.8/lib/python3.8/site-packages/opensmile/core/smile.py:308: UserWarning: Segment too short, filling with NaN.
#   warnings.warn(
# 100%|██████████| 3260/3260 [50:21<00:00,  1.08it/s]

# %% [markdown]
# ### **Fixed** file duration

# %%
DURATION_S = 15

# %%
def _extract_parse_smile_duration(
    s: opensmile.Smile, f: Path, duration_s: float
) -> pd.DataFrame:
    sr, wav_arr = wavfile.read(f)

    # we extract features until the penultimate second of the utterance
    t_end = (wav_arr.shape[0] / sr) - 2
    t_start = max(1, t_end - duration_s)

    df_feat = s.process_file(
        file=str(f.absolute()),
        start=t_start,
        end=t_end,
    )

    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat['file'].astype(str)

    # df_feat["fileName"] = f.name
    df_feat["pic_name"] = f.name.split("__")[0]
    df_feat["time_str"] = f.name.split("__")[1].split(".")[0]
    df_feat["DB"] = f.parent.name
    df_feat["ID"] = f.parent.parent.name.split("__")[-1]
    return df_feat


def _extract_opensmile_f_duration(file_duration) -> Tuple[pd.DataFrame, ...]:
    file, duration = file_duration
    # calculate the global utterance features
    return (
        _extract_parse_smile_duration(func_gemaps, f=file, duration_s=duration),
        _extract_parse_smile_duration(lld_gemaps, f=file, duration_s=duration),
        _extract_parse_smile_duration(lld_compare, f=file, duration_s=duration),
    )


out = None
with Pool(processes=8) as pool:
    wav_files = list(speech_data_session_dir.glob("*/*/*.wav"))
    wav_files = [(wf, DURATION_S) for wf in wav_files]
    results = pool.imap_unordered(_extract_opensmile_f_duration, wav_files)
    results = tqdm(results, total=len(wav_files))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()


def _parse_concat_df(df_conc: pd.DataFrame) -> pd.DataFrame:
    df_conc["DB"] = df_conc["DB"].astype("category")
    df_conc["pic_name"] = df_conc["pic_name"].astype("category")
    df_conc["ID"] = df_conc["ID"].astype("category")
    return df_conc


df_gemaps_func_dur = _parse_concat_df(pd.concat([o[0] for o in out], ignore_index=True))
df_gemaps_lld_dur = _parse_concat_df(pd.concat([o[1] for o in out], ignore_index=True))
df_compare_lld_dur = _parse_concat_df(pd.concat([o[2] for o in out], ignore_index=True))

del (
    out,
    _extract_opensmile_f_duration,
    _parse_concat_df,
    _extract_parse_smile_duration,
)

# %% [markdown]
# ## Extract `F0`-range from the LLD's

# %%
import numpy as np
from tsflex.features import FuncWrapper
from tsflex.features.utils import make_robust

# %%
def quantile_nz(a: np.ndarray, q=List[float]) -> List[Optional[float]]:
    a_nz = a[a > 0]
    if len(a_nz):
        return np.quantile(a_nz, q=q)
    else:
        return [None] * len(q)

def std_nz(a: np.ndarray) -> Optional[float]:
    a_nz = a[a > 0]
    if len(a_nz):
        return np.std(a_nz)
    return None

def nonzero_count(a: np.ndarray) -> int:
    return sum(a > 0)


def return_func_series_list(a: np.ndarray, f_list: List[FuncWrapper]) -> pd.Series:
    s = pd.Series(dtype="float64")
    for f in f_list:
        s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
    return s.sort_index()


qs = sum([[1 - q, q] for q in [0, 0.01, 0.02, 0.03, 0.05, 0.1, 0.15, 0.2]], []) + [0.5]
display(str(qs))
# Out:
# '[1, 0, 0.99, 0.01, 0.98, 0.02, 0.97, 0.03, 0.95, 0.05, 0.9, 0.1, 0.85, 0.15, 0.8, 0.2, 0.5]'

# %% [markdown]
# ### GeMAPS LLD

# %% [markdown]
# #### Whole duration

# %%
df_gemaps_lld.filter(like="F0").columns
# logRelF0-H1-H2_sma3nz -> log freq difference between the harmonics
# SMA -> moving average window
# NZ -> no-zero
# Out:
# Index(['F0semitoneFrom27.5Hz_sma3nz', 'logRelF0-H1-H2_sma3nz',
#        'logRelF0-H1-A3_sma3nz', 'F1amplitudeLogRelF0_sma3nz',
#        'F2amplitudeLogRelF0_sma3nz', 'F3amplitudeLogRelF0_sma3nz'],
#       dtype='object')

# %%
# define the signal on which the function will be performed, and the functions
s_name = "F0semitoneFrom27.5Hz_sma3nz"

f_gemaps_lld_funcs: List[FuncWrapper] = [
    make_robust(
        FuncWrapper(quantile_nz, output_names=[s_name + f"_q={q}" for q in qs], q=qs),
        min_nb_samples=3,
        passthrough_nans=False,
    ),
    make_robust(FuncWrapper(nonzero_count, output_names=[f"{s_name}_nzcount"])),
    make_robust(FuncWrapper(std_nz, output_names=[f"{s_name}_std"])),
]

# Apply the functions on each group
df_gemaps_lld_F0 = (
    df_gemaps_lld.groupby(by=["file"])[[s_name]]
    .apply(lambda x: return_func_series_list(x.values, f_list=f_gemaps_lld_funcs))
    .reset_index()
)
display(df_gemaps_lld_F0)
# Out:
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
#                                                    file  \
# 0     /media/speech_webapp_cleaned/backup/2020-11-26...
# 1     /media/speech_webapp_cleaned/backup/2020-11-26...
# 2     /media/speech_webapp_cleaned/backup/2020-11-26...
# 3     /media/speech_webapp_cleaned/backup/2020-11-26...
# 4     /media/speech_webapp_cleaned/backup/2020-11-26...
# ...                                                 ...
# 3255  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3256  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3257  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3258  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3259  /media/speech_webapp_cleaned/backup/2022-07-29...
#
#       F0semitoneFrom27.5Hz_sma3nz_nzcount  F0semitoneFrom27.5Hz_sma3nz_q=0  \
# 0                                  5606.0                        12.251042
# 1                                  6669.0                        12.058680
# 2                                  5844.0                        12.202407
# 3                                  8443.0                        12.125778
# 4                                  6159.0                        12.189971
# ...                                   ...                              ...
# 3255                               1207.0                        12.081606
# 3256                               1147.0                        12.122270
# 3257                               1129.0                        12.099364
# 3258                               1178.0                        12.042550
# 3259                               1255.0                        12.116116
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.01  F0semitoneFrom27.5Hz_sma3nz_q=0.02  \
# 0                              13.934838                           14.599903
# 1                              13.842417                           14.423253
# 2                              13.778239                           14.236030
# 3                              13.991558                           14.645151
# 4                              13.662513                           14.442118
# ...                                  ...                                 ...
# 3255                           12.333227                           14.234591
# 3256                           12.416688                           12.569788
# 3257                           12.852855                           13.356646
# 3258                           12.434628                           12.837402
# 3259                           12.259661                           12.595460
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.03  F0semitoneFrom27.5Hz_sma3nz_q=0.05  \
# 0                              14.984331                           15.436341
# 1                              14.856564                           15.276927
# 2                              14.644257                           15.155413
# 3                              14.944079                           15.383024
# 4                              14.943714                           15.459200
# ...                                  ...                                 ...
# 3255                           15.495650                           16.751472
# 3256                           12.722285                           13.154190
# 3257                           14.185842                           15.858899
# 3258                           13.191461                           15.476952
# 3259                           13.308410                           15.067689
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.1  F0semitoneFrom27.5Hz_sma3nz_q=0.15  \
# 0                             16.219905                           19.077585
# 1                             16.208848                           19.443033
# 2                             16.168508                           19.076534
# 3                             15.988630                           17.458601
# 4                             17.056338                           20.813693
# ...                                 ...                                 ...
# 3255                          17.717968                           18.184064
# 3256                          16.428841                           16.939161
# 3257                          16.714621                           17.751991
# 3258                          16.605111                           17.161470
# 3259                          17.149657                           17.711291
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.2  F0semitoneFrom27.5Hz_sma3nz_q=0.5  \
# 0                             21.401300                          23.277583
# 1                             21.618110                          23.451925
# 2                             21.514988                          23.319512
# 3                             20.491598                          23.273064
# 4                             22.235821                          23.349960
# ...                                 ...                                ...
# 3255                          18.838248                          30.589996
# 3256                          17.635229                          30.006018
# 3257                          18.508284                          30.441248
# 3258                          17.578321                          30.261019
# 3259                          18.406685                          30.926809
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.8  F0semitoneFrom27.5Hz_sma3nz_q=0.85  \
# 0                             25.690542                           26.900887
# 1                             26.041262                           26.716160
# 2                             25.941892                           26.545710
# 3                             25.555413                           26.574199
# 4                             25.271851                           26.260371
# ...                                 ...                                 ...
# 3255                          34.799860                           35.623919
# 3256                          33.042439                           33.739609
# 3257                          33.191100                           34.591146
# 3258                          33.462995                           34.710780
# 3259                          34.802098                           35.819084
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.9  F0semitoneFrom27.5Hz_sma3nz_q=0.95  \
# 0                             27.558018                           28.568579
# 1                             27.476436                           28.203361
# 2                             27.309220                           27.936713
# 3                             27.526564                           28.037846
# 4                             27.144308                           28.023798
# ...                                 ...                                 ...
# 3255                          36.578542                           37.130973
# 3256                          35.319817                           36.723486
# 3257                          35.719296                           37.349375
# 3258                          35.625403                           36.458971
# 3259                          36.653497                           38.139115
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.97  F0semitoneFrom27.5Hz_sma3nz_q=0.98  \
# 0                              32.494460                           34.903307
# 1                              29.057006                           31.833231
# 2                              30.257185                           33.922007
# 3                              29.437154                           32.693497
# 4                              29.963233                           31.603961
# ...                                  ...                                 ...
# 3255                           37.724056                           38.851741
# 3256                           37.391315                           38.017653
# 3257                           38.074427                           38.498878
# 3258                           36.714640                           37.069306
# 3259                           58.072935                           61.487496
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.99  F0semitoneFrom27.5Hz_sma3nz_q=1  \
# 0                              35.731693                        60.804386
# 1                              35.101993                        60.076370
# 2                              35.548235                        60.912628
# 3                              35.109045                        60.835857
# 4                              35.470180                        60.711689
# ...                                  ...                              ...
# 3255                           39.343193                        59.869705
# 3256                           61.607289                        62.090675
# 3257                           39.238436                        60.109604
# 3258                           37.830679                        61.561722
# 3259                           61.839945                        62.154469
#
#       F0semitoneFrom27.5Hz_sma3nz_std
# 0                            4.560182
# 1                            4.228516
# 2                            4.578349
# 3                            4.559110
# 4                            4.181477
# ...                               ...
# 3255                         7.346724
# 3256                         8.707480
# 3257                         7.307754
# 3258                         7.605315
# 3259                         9.434835
#
# [3260 rows x 20 columns]

# %% [markdown]
# #### Fixed duration

# %%
# define the signal on which the function will be performed, and the functions
s_name = "F0semitoneFrom27.5Hz_sma3nz"

f_gemaps_lld_funcs: List[FuncWrapper] = [
    make_robust(
        FuncWrapper(quantile_nz, output_names=[s_name + f"_q={q}" for q in qs], q=qs),
        min_nb_samples=3,
        passthrough_nans=False,
    ),
    make_robust(FuncWrapper(nonzero_count, output_names=[f"{s_name}_nzcount"])),
    make_robust(FuncWrapper(std_nz, output_names=[f"{s_name}_std"])),
]

# Apply the functions on each group
df_gemaps_lld_F0_dur = (
    df_gemaps_lld_dur.groupby(by=["file"])[[s_name]]
    .apply(lambda x: return_func_series_list(x.values, f_list=f_gemaps_lld_funcs))
    .reset_index()
)
display(df_gemaps_lld_F0_dur)
# Out:
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.9  F0semitoneFrom27.5Hz_sma3nz_q=0.95  \
# 0                             27.369186                           27.826359
# 1                             27.780138                           28.776328
# 2                             27.317442                           29.821573
# 3                             27.746759                           27.930443
# 4                             27.533591                           28.011135
# ...                                 ...                                 ...
# 3255                          36.620591                           37.576349
# 3256                          35.801359                           37.544811
# 3257                          35.820171                           38.155293
# 3258                          35.892273                           36.452871
# 3259                          36.695087                           38.383422
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.97  F0semitoneFrom27.5Hz_sma3nz_q=0.98  \
# 0                              28.527192                           30.504682
# 1                              33.891972                           34.911347
# 2                              33.787843                           35.250256
# 3                              28.057064                           28.556473
# 4                              28.523093                           29.330261
# ...                                  ...                                 ...
# 3255                           38.889307                           39.313846
# 3256                           61.093627                           61.491940
# 3257                           38.973419                           39.279740
# 3258                           36.661359                           37.243609
# 3259                           57.125804                           59.611215
#
#       F0semitoneFrom27.5Hz_sma3nz_q=0.99  F0semitoneFrom27.5Hz_sma3nz_q=1  \
# 0                              34.926117                        53.513889
# 1                              35.400385                        36.192989
# 2                              38.547446                        60.687878
# 3                              34.381355                        60.852364
# 4                              34.209718                        35.575684
# ...                                  ...                              ...
# 3255                           39.500855                        59.869705
# 3256                           61.853252                        62.090675
# 3257                           39.621155                        60.109604
# 3258                           37.556779                        61.561722
# 3259                           61.484190                        61.889057
#
#       F0semitoneFrom27.5Hz_sma3nz_std
# 0                            4.343889
# 1                            3.927652
# 2                            4.352689
# 3                            4.735933
# 4                            3.395312
# ...                               ...
# 3255                         7.338382
# 3256                         9.630668
# 3257                         7.522724
# 3258                         8.075009
# 3259                         9.421097
#
# [3260 rows x 20 columns]

# %% [markdown]
# ### ComPaRE LLD

# %% [markdown]
# #### whole duration

# %%
df_compare_lld.filter(like="F0").columns
# Out:
# Index(['F0final_sma'], dtype='object')

# %%
s_name = "F0final_sma"

f_compare_lld_funcs: List[FuncWrapper] = [
    make_robust(
        FuncWrapper(quantile_nz, output_names=[s_name + f"_q={q}" for q in qs], q=qs),
        min_nb_samples=3,
        passthrough_nans=False,
    ),
    make_robust(FuncWrapper(nonzero_count, output_names=[f"{s_name}_nzcount"])),
    make_robust(FuncWrapper(std_nz, output_names=[f"{s_name}_std"])),
]

df_compare_lld_F0 = (
    df_compare_lld.groupby(by=["file"])[[s_name]]
    .apply(lambda x: return_func_series_list(x.values, f_list=f_compare_lld_funcs))
    .reset_index()
)
display(df_compare_lld_F0)
# Out:
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
#                                                    file  F0final_sma_nzcount  \
# 0     /media/speech_webapp_cleaned/backup/2020-11-26...               5622.0
# 1     /media/speech_webapp_cleaned/backup/2020-11-26...               6730.0
# 2     /media/speech_webapp_cleaned/backup/2020-11-26...               5888.0
# 3     /media/speech_webapp_cleaned/backup/2020-11-26...               8482.0
# 4     /media/speech_webapp_cleaned/backup/2020-11-26...               6184.0
# ...                                                 ...                  ...
# 3255  /media/speech_webapp_cleaned/backup/2022-07-29...               1228.0
# 3256  /media/speech_webapp_cleaned/backup/2022-07-29...               1204.0
# 3257  /media/speech_webapp_cleaned/backup/2022-07-29...               1163.0
# ...                  ...              ...              ...
# 3255          265.805937       273.261505        56.675216
# 3256          239.594741       253.532104        55.602199
# 3257          261.448510       273.304169        54.954997
# 3258          241.654327       480.455841        56.908717
# 3259          254.371584       264.469025        58.471586
#
# [3260 rows x 20 columns]

# %%
del df_compare_lld, df_gemaps_lld

# %% [markdown]
# #### Fixed duration

# %%
s_name = "F0final_sma"

f_compare_lld_funcs: List[FuncWrapper] = [
    make_robust(
        FuncWrapper(quantile_nz, output_names=[s_name + f"_q={q}" for q in qs], q=qs),
        min_nb_samples=3,
        passthrough_nans=False,
    ),
    make_robust(FuncWrapper(nonzero_count, output_names=[f"{s_name}_nzcount"])),
    make_robust(FuncWrapper(std_nz, output_names=[f"{s_name}_std"])),
]

df_compare_lld_F0_dur = (
    df_compare_lld_dur.groupby(by=["file"])[[s_name]]
    .apply(lambda x: return_func_series_list(x.values, f_list=f_compare_lld_funcs))
    .reset_index()
)
display(df_compare_lld_F0_dur)
# Out:
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
# /tmp/ipykernel_45991/3620613513.py:21: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.concat([s, pd.Series(data=f(a), index=f.output_names)])
#                                                    file  F0final_sma_nzcount  \
# 0     /media/speech_webapp_cleaned/backup/2020-11-26...               1110.0
# 1     /media/speech_webapp_cleaned/backup/2020-11-26...               1137.0
# 2     /media/speech_webapp_cleaned/backup/2020-11-26...               1184.0
# 3     /media/speech_webapp_cleaned/backup/2020-11-26...               1097.0
# 4     /media/speech_webapp_cleaned/backup/2020-11-26...               1232.0
# ...                                                 ...                  ...
# 3255  /media/speech_webapp_cleaned/backup/2022-07-29...                537.0
# 3256  /media/speech_webapp_cleaned/backup/2022-07-29...                484.0
# 3257  /media/speech_webapp_cleaned/backup/2022-07-29...                513.0
# 3258  /media/speech_webapp_cleaned/backup/2022-07-29...                512.0
# 3259  /media/speech_webapp_cleaned/backup/2022-07-29...                527.0
#
#       F0final_sma_q=0  F0final_sma_q=0.01  F0final_sma_q=0.02  \
# 0           52.515720           59.550177           61.644557
# 1           52.169254           58.053143           60.028618
# 2           52.456104           54.270726           58.549653
# 3           52.258652           57.555002           61.642259
# 4           52.972012           57.447994           60.514348
# ...               ...                 ...                 ...
# 3255        52.411278           53.815871           54.473767
# 3256        52.487247           53.489115           53.905257
# 3257        52.773777           53.723000           54.336057
# 3258        53.005619           53.948271           54.624933
# 3259        53.176605           54.078633           54.395267
#
#       F0final_sma_q=0.03  F0final_sma_q=0.05  F0final_sma_q=0.1  \
# 0              63.415400           65.251291          68.541936
# 1              61.909581           64.787181          69.921494
# 2              61.314212           64.047336          73.038348
# 3              63.632233           65.603233          68.605052
# 4              63.565456           67.601669          88.101160
# ...                  ...                 ...                ...
# 3255           55.182697           58.448596          74.618364
# 3256           54.274060           54.706801          56.499628
# 3257           54.840268           56.111498          65.511383
# 3258           55.173694           56.416730          62.703044
# 3259           54.807897           55.878756          64.810042
#
#       F0final_sma_q=0.15  F0final_sma_q=0.2  F0final_sma_q=0.5  \
# 0              71.334982          86.079478         101.478558
# 1              88.439491          96.671332         106.136009
# 2              91.204002          96.796397         105.504154
# 3              70.291788          82.021001         102.886314
# 4              97.584045         100.475096         107.414379
# ...                  ...                ...                ...
# 3255           79.244200          86.137927         161.384293
# 3256           60.450850          72.390379         150.863167
# 3257           72.927167          78.666809         159.579422
# 3258           72.016611          74.807172         155.291420
# 3259           73.438358          75.427423         162.632187
#
#       F0final_sma_q=0.8  F0final_sma_q=0.85  F0final_sma_q=0.9  \
# 0            120.907774          127.066941         133.397832
# 1            122.955678          129.919092         136.964676
# 2            119.886519          126.595753         133.235713
# 3            120.972205          131.653961         136.536163
# 4            126.072002          130.589661         135.145366
# ...                 ...                 ...                ...
# 3255         207.541605          212.280011         226.131650
# 3256         183.178098          185.703445         198.102008
# 3257         192.413712          201.826782         212.936194
# 3258         196.385416          208.469205         217.509985
# 3259         196.975552          211.216345         220.007779
#
#       F0final_sma_q=0.95  F0final_sma_q=0.97  F0final_sma_q=0.98  \
# 0             137.053220          144.247558          164.291497
# 1             143.642413          175.066255          203.429737
# 2             157.287839          193.613500          210.703262
# 3             138.035153          139.013577          142.655715
# 4             139.316591          142.847991          151.438947
# ...                  ...                 ...                 ...
# 3255          235.083456          250.921192          261.007480
# 3256          221.243517          231.749359          238.248474
# 3257          247.267242          254.604106          262.980389
# 3258          225.339508          228.183186          235.059670
# 3259          230.626530          240.122482          247.528763
#
#       F0final_sma_q=0.99  F0final_sma_q=1  F0final_sma_std
# 0             207.567622       605.024841        36.802723
# 1             211.766790       214.966629        26.602538
# 2             259.345192       611.399170        39.907779
# 3             199.030864       616.790710        41.025275
# 4             199.253249       214.674286        21.754796
# ...                  ...              ...              ...
# 3255          266.620685       273.261505        56.058366
# 3256          245.759638       253.532104        56.461768
# 3257          268.844015       273.304169        57.112913
# 3258          237.844198       480.455841        60.560208
# 3259          252.926218       261.860840        58.731429
#
# [3260 rows x 20 columns]

# %%
# df_compare_lld_F0_dur['F0final_sma_nzcount'].value_counts()

# %% [markdown]
# # Join into one big dataframe

# %% [markdown]
# ## Whole duration

# %%
df_feat_tot = df_gemaps_func.merge(
    df_gemaps_lld_F0,
    on=["file"],
).merge(df_compare_lld_F0, on=["file"])

display(df_feat_tot)

df_feat_tot.to_parquet(loc_data_dir.joinpath("df_speech_feat_tot.parquet"), engine='fastparquet')
# Out:
#                                                    file  start  \
# 0     /media/speech_webapp_cleaned/backup/2020-11-26... 0 days
# 1     /media/speech_webapp_cleaned/backup/2020-11-26... 0 days
# 2     /media/speech_webapp_cleaned/backup/2020-11-26... 0 days
# 3     /media/speech_webapp_cleaned/backup/2020-11-26... 0 days
# 4     /media/speech_webapp_cleaned/backup/2020-11-26... 0 days
# ...                                                 ...    ...
# 3255  /media/speech_webapp_cleaned/backup/2022-07-29... 0 days
# 3256  /media/speech_webapp_cleaned/backup/2022-07-29... 0 days
# 3257  /media/speech_webapp_cleaned/backup/2022-07-29... 0 days
# 3258  /media/speech_webapp_cleaned/backup/2022-07-29... 0 days
# 3259  /media/speech_webapp_cleaned/backup/2022-07-29... 0 days
#
#                            end  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 
# 2             147.934433          152.668022          154.929968
# 3             151.755722          162.659708          167.707507
# 4             147.923180          155.662360          159.461169
# ...                  ...                 ...                 ...
# 3255          209.769741          220.269680          229.243279
# 3256          222.409668          229.993871          242.759653
# 3257          245.481996          267.474963          278.823220
# 3258          215.745352          221.694379          263.348202
# 3259          223.834353          244.800968          264.892119
#
#       F0final_sma_q=0.99  F0final_sma_q=1  F0final_sma_std
# 0             180.676071       261.382050        26.145859
# 1             212.089901       407.436768        31.185211
# 2             162.721475       213.333603        22.587254
# 3             181.804877       582.304810        35.289525
# 4             179.427890       604.380737        32.479560
# ...                  ...              ...              ...
# 3255          242.962517       287.092896        53.060605
# 3256          261.307195       279.645294        56.203512
# 3257          296.340424       342.739563        56.406376
# 3258          273.055754       499.169189        52.317964
# 3259          278.609238       318.297180        57.232456
#
# [3260 rows x 107 columns]

# %% [markdown]
# ## Fixed duration

# %%
df_feat_tot_dur = df_gemaps_func_dur.merge(
    df_gemaps_lld_F0_dur,
    on=["file"],
).merge(df_compare_lld_F0_dur, on=["file"])

display(df_feat_tot_dur)

df_feat_tot_dur.to_parquet(loc_data_dir.joinpath(f"df_speech_feat_tot_{DURATION_S}s.parquet"), engine='fastparquet')
# Out:
#                                                    file  \
# 0     /media/speech_webapp_cleaned/backup/2020-11-26...
# 1     /media/speech_webapp_cleaned/backup/2020-11-26...
# 2     /media/speech_webapp_cleaned/backup/2020-11-26...
# 3     /media/speech_webapp_cleaned/backup/2020-11-26...
# 4     /media/speech_webapp_cleaned/backup/2020-11-26...
# ...                                                 ...
# 3255  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3256  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3257  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3258  /media/speech_webapp_cleaned/backup/2022-07-29...
# 3259  /media/speech_webapp_cleaned/backup/2022-07-29...
#
#                          start                       end  \
# 0              0 days 00:00:00 0 days 00:00:09.820498866
# 1              0 days 00:00:00 0 days 00:00:10.099138322
# 2              0 days 00:00:00 0 days 00:00:11.631655329
# 3              0 days 00:00:00 0 days 00:00:10.006258503
# 4              0 days 00:00:00 0 days 00:00:10.888616780
# ...                        ...                       ...
# 3255           0 days 00:00:00 0 days 00:00:13.933333333
# 3256           0 days 00:00:00    0 days 00:00:13.336000
# 3257 0 days 00:00:01.365333333 0 days 00:00:16.365333333
# 3258    0 days 00:00:00.768000    0 days 00:00:15.768000
# 3259           0 days 00:00:00 0 days 00:00:14.274666667
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                             24.239685
# 1                             23.929838
# 2                             24.491964
# 3                             24.363800
# 4                             24.334663
# ...                                 ...
# 3255                          28.138924
# 3256                          27.315117
# 3257                          30.677828
# 3258                          30.371105
# 3259                          29.246935
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.197734
# 1                                   0.226161
# 2                                   0.209518
# 3                                   0.149572
# 4                                   0.196280
# ...                                      ...
# 3255                                0.262838
# 3256                                0.283532
# 3257                                0.252255
# 3258                                0.222629
# 3259                                0.234704
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                      21.465519
# 1                                      21.023754
# 2                                      20.766779
# 3                                      22.219257
# 4                                      21.857309
# ...                                          ...
# 3255                                   19.160347
# 3256                                   18.290337
# 3257                                   24.055370
# 3258                                   25.565237
# 3259                                   22.871061
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                      24.568817
# 1                                      24.046206
# 2                                      24.849165
# 3                                      24.683170
# 4                                      24.649261
# ...                                          ...
# 3255                                   31.739861
# 3256                                   30.543329
# 3257                                   31.893747
# 3258                                   32.238106
# 3259                                   31.227327
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                      27.071358
# 1                                      27.551891
# 2                                      27.832775
# 3                                      27.130074
# 4                                      27.470707
# ...                                          ...
# 3255                                   33.588272
# 3256                                   33.412140
# 3257                                   34.709621
# 3258                                   33.837151
# 3259                                   32.679203
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     5.605839
# 1                                     6.528137
# 2                                     7.065996
# 3                                     4.910816
# 4                                     5.613398
# ...                                        ...
# 3255                                 14.427925
# 3256                                 15.121803
# 3257                                 10.654251
# 3258                                  8.271914
# 3259                                  9.808142
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  ...  F0final_sma_q=0.5  \
# 0                                      164.067108  ...         113.018311
# 1                                      187.470551  ...         109.989197
# 2                                      270.519897  ...         115.703796
# 3                                      164.576767  ...         114.378471
# 4                                      359.110016  ...         113.053253
# ...                                           ...  ...                ...
# 3255                                   196.351608  ...         171.155106
# 3256                                   193.817444  ...         158.235748
# 3257                                   179.117371  ...         171.572083
# 3258                                   237.301773  ...         175.540901
# 3259                                   211.052551  ...         166.530640
#
#       F0final_sma_q=0.8  F0final_sma_q=0.85  F0final_sma_q=0.9  \
# 0            131.158914          135.485562         140.365036
# 1            135.128052          138.201920         143.146164
# 2            137.047739          140.613589         146.052365
# 3            131.793457          135.502396         141.114517
# 4            134.071762          137.082139         145.200926
# ...                 ...                 ...                ...
# 3255         189.764621          195.777077         204.598672
# 3256         188.038403          198.451437         204.818040
# 3257         201.461716          208.563187         229.595581
# 3258         193.481689          197.513123         214.686882
# 3259         180.777460          184.894058         194.980646
#
#       F0final_sma_q=0.95  F0final_sma_q=0.97  F0final_sma_q=0.98  \
# 0             154.196330          159.312083          168.390383
# 1             149.917130          153.857654          156.913052
# 2             160.558090          165.840691          178.470654
# 3             147.558517          153.772034          154.565555
# 4             152.648600          201.115561          205.246506
# ...                  ...                 ...                 ...
# 3255          211.460495          222.457440          236.238565
# 3256          216.968382          229.354390          244.414448
# 3257          263.805341          273.710258          279.181036
# 3258          242.040451          264.340080          272.734589
# 3259          215.270633          218.074289          219.546282
#
#       F0final_sma_q=0.99  F0final_sma_q=1  F0final_sma_std
# 0             199.963067       604.380737        42.406215
# 1             196.515714       261.382050        29.029921
# 2             375.313575       582.304810        45.648519
# 3             160.630338       213.333603        22.949861
# 4             212.750762       407.436768        36.997951
# ...                  ...              ...              ...
# 3255          265.332869       272.520050        55.636780
# 3256          270.704076       287.092896        55.441265
# 3257          288.200612       341.743896        59.520005
# 3258          283.056671       317.864655        56.384059
# 3259          221.904251       499.169189        50.933680
#
# [3260 rows x 107 columns]

# %% [markdown]
# ---

# %%
df_feat_tot['file'].map(lambda x: '/'.join(x.split('/')[-3:]))

# %%
df_feat_tot[['file', 'DB', 'pic_name', 'time_str', 'ID']]
