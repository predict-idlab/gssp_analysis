# %% [markdown]
# # Speech Feature Extraction using OpenSMILE (GeMapsv01b config)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import traceback
from multiprocessing import Pool
from pathlib import Path
from typing import List, Optional, Tuple

import numpy as np
import opensmile
import pandas as pd
from IPython.display import display
from tqdm.auto import tqdm

sys.path.append("..")
from sgs_utils.path_conf import interim_speech_data_dir, loc_data_dir

# %% [markdown]
# # Extracting features

# %% [markdown]
# useful links:
# * [opensmile config folder](https://github.com/audeering/opensmile/tree/v3.0.0/config)
# * difference between GeMAPS versions [here](https://github.com/audeering/opensmile/blob/v3.0.0/config/gemaps/CHANGES.txt')
#
# **note**: `eGeMAPS` is an _extended_ version of the GeMAPS
#
# feature-level`
# * `Functionals`: global segment based features (1 feature per segment)
# * `LowLevelDescriptor`: sliding window features (1 feature per window)

# %%
# Load the VAD dataframe
df_session: pd.DataFrame = pd.read_parquet(
    loc_data_dir.joinpath("df_session_tot_cleaned_VAD.parquet")
)

# define the feature extraction configs
func_gemaps: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.Functionals,
)

func_compare: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

(df_session.VAD_sliced_duration_s > 15).value_counts()
# Out:
# True     2909
# False     348
# Name: VAD_sliced_duration_s, dtype: int64

# %%
# Helper functions
def _extract_parse_smile_duration(
    s: opensmile.Smile,
    arr_path: Path,
    start_s: Optional[float] = None,
    end_s: Optional[float] = None,
) -> pd.DataFrame:
    wav_arr = np.load(arr_path)
    wav_path = arr_path.with_suffix(".wav")
    sr = 16_000

    df_feat = s.process_signal(
        signal=np.load(str(arr_path.absolute())),
        sampling_rate=sr,
        file=str(wav_path),
        start=start_s,
        end=end_s,
    )

    df_feat = df_feat.reset_index(drop=False)
    df_feat["file"] = df_feat["file"].astype(str)

    df_feat["pic_name"] = arr_path.name.split("__")[0]
    df_feat["time_str"] = arr_path.name.split("__")[1].split(".")[0]
    df_feat["DB"] = arr_path.parent.name
    df_feat["ID"] = arr_path.parent.parent.name.split("__")[-1]
    return df_feat


def _parse_concat_df(df_conc: pd.DataFrame) -> pd.DataFrame:
    df_conc["DB"] = df_conc["DB"].astype("category")
    df_conc["pic_name"] = df_conc["pic_name"].astype("category")
    df_conc["ID"] = df_conc["ID"].astype("category")
    return df_conc

# %% [markdown]
# ## **`Functionals`**: `Fixed duration`

# %%
DURATION_S = 15

# %%
def _extract_opensmile_f_duration(file_start_end) -> Tuple[pd.DataFrame, ...]:
    file, start, end = file_start_end
    # calculate the global utterance features
    return (
        _extract_parse_smile_duration(
            func_gemaps, arr_path=file, start_s=start, end_s=end
        ),
        # _extract_parse_smile_duration(
        #     func_compare, arr_path=file, start_s=start, end_s=end
        # ),
    )

# %% [markdown]
# ### first 15 seconds

# %%
# construct an array which contains the file path and the start and end time
# the start and end time are in this case [0, 15] seconds
arr_file_start_end: List[Tuple[Path, float, float]] = [
    (
        interim_speech_data_dir
        / "VAD_slice_16khz"
        / r.ID
        / r.DB
        / f"{r.pic_name}__{r.time_str}.npy",
        0,
        DURATION_S,
    )
    for _, r in df_session[df_session.VAD_sliced_duration_s > DURATION_S].iterrows()
]
print(len(arr_file_start_end))

out: List = []
with Pool(processes=8) as pool:
    results = pool.imap_unordered(_extract_opensmile_f_duration, arr_file_start_end)
    results = tqdm(results, total=len(arr_file_start_end))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()

df_gemaps_func_dur_start = _parse_concat_df(
    pd.concat([o[0] for o in out], ignore_index=True)
)
# df_compare_func_dur_start = _parse_concat_df(
#     pd.concat([o[1] for o in out], ignore_index=True)
# )

del out, pool, results, arr_file_start_end
# Out:
# 2909
#   0%|          | 0/2909 [00:00<?, ?it/s]

# %%
df_gemaps_func_dur_start.to_parquet(
    loc_data_dir / f"df_gemaps_{DURATION_S}s_start.parquet",
    engine="fastparquet",
)

# df_compare_func_dur_start.to_parquet(
#     loc_data_dir / f"df_compare_{DURATION_S}s_start.parquet",
#     engine="fastparquet",
# )

# %% [markdown]
# ### Last 15 seconds

# %%
# construct an array which contains the file path and the start and end time
# the start and end time are in this case [V_end - 15, VAD_end] seconds
arr_file_start_end: List[Tuple[Path, float, float]] = [
    (
        interim_speech_data_dir
        / "VAD_slice_16khz"
        / r.ID
        / r.DB
        / f"{r.pic_name}__{r.time_str}.npy",
        r.VAD_sliced_duration_s - DURATION_S,
        r.VAD_sliced_duration_s,
    )
    for _, r in df_session[df_session.VAD_sliced_duration_s > DURATION_S].iterrows()
]
print(len(arr_file_start_end))

out: List = []
with Pool(processes=8) as pool:
    results = pool.imap_unordered(_extract_opensmile_f_duration, arr_file_start_end)
    results = tqdm(results, total=len(arr_file_start_end))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()

df_gemaps_func_dur_end = _parse_concat_df(
    pd.concat([o[0] for o in out], ignore_index=True)
)
# df_compare_func_dur_end = _parse_concat_df(
#     pd.concat([o[1] for o in out], ignore_index=True)
# )

del out, _extract_opensmile_f_duration
# Out:
# 2909
#   0%|          | 0/2909 [00:00<?, ?it/s]

# %%
df_gemaps_func_dur_end.to_parquet(
    loc_data_dir / f"df_gemaps_{DURATION_S}s_end.parquet",
    engine="fastparquet",
)

# df_compare_func_dur_end.to_parquet(
#     loc_data_dir / f"df_compare_{DURATION_S}s_end.parquet",
#     engine="fastparquet",
# )

# %% [markdown]
# ## **`LLDs`**: `Whole duration`

# %%
lld_gemaps = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# we will use the ComParE LLD to calculate frequency-based features on `F0final_sma`
lld_compare = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# %%
def _extract_opensmile_f_whole_duration(file) -> Tuple[pd.DataFrame, ...]:
    # calculate the global utterance features
    return (
        _extract_parse_smile_duration(lld_gemaps, arr_path=file),
        _extract_parse_smile_duration(lld_compare, arr_path=file),
    )


# The list of files to extract the features from
arr_files: List[Path] = list(
    (interim_speech_data_dir / "full_dur_16khz").glob("**/*.npy")
)


out = None
with Pool(processes=8) as pool:
    results = pool.imap_unordered(_extract_opensmile_f_whole_duration, arr_files)
    results = tqdm(results, total=len(arr_files))
    try:
        out = [f for f in results]
    except:
        traceback.print_exc()
        pool.terminate()
    finally:
        pool.close()
        pool.join()

df_gemaps_lld = _parse_concat_df(
    pd.concat([o[0] for o in out], ignore_index=True)
).assign(
    file=lambda D: D["file"].astype("str").astype("category"),
    time_str=lambda D: D["time_str"].astype("str").astype("category"),
    end=lambda D: D["end"].dt.total_seconds().astype(np.float32),
    start=lambda D: D["start"].dt.total_seconds().astype(np.float32),
)

df_compare_lld = _parse_concat_df(
    pd.concat([o[1] for o in out], ignore_index=True)
).assign(
    file=lambda D: D["file"].astype("str").astype("category"),
    time_str=lambda D: D["time_str"].astype("str").astype("category"),
    end=lambda D: D["end"].dt.total_seconds().astype(np.float32),
    start=lambda D: D["start"].dt.total_seconds().astype(np.float32),
)

del out, arr_files, results, pool
# Out:
#   0%|          | 0/3233 [00:00<?, ?it/s]

# %%
df_gemaps_lld.to_parquet(
    loc_data_dir / f"df_gemaps_lld_full_dur.parquet",
    engine="fastparquet",
)

# %%
comp_cols = [
    "F0final_sma",
    "voicingFinalUnclipped_sma",
    "jitterLocal_sma",
    "jitterDDP_sma",
    "shimmerLocal_sma",
    "logHNR_sma",
    "audspec_lengthL1norm_sma",
    "audspecRasta_lengthL1norm_sma",
    "pcm_RMSenergy_sma",
    "pcm_zcr_sma",
    "audSpec_Rfilt_sma[0]",
    "pcm_fftMag_spectralFlux_sma",
    "pcm_fftMag_spectralEntropy_sma",
    "pcm_fftMag_spectralVariance_sma",
    # "pcm_fftMag_spectralSkewness_sma",
    # "pcm_fftMag_spectralKurtosis_sma",
    # "pcm_fftMag_spectralSlope_sma",
    # "pcm_fftMag_psySharpness_sma",
    "pcm_fftMag_spectralHarmonicity_sma",
    "mfcc_sma[1]",
]

df_compare_lld[['file', 'start', 'end', 'pic_name', 'time_str', 'DB', 'ID'] + comp_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17004953 entries, 0 to 17004952
# Data columns (total 23 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   file                                category
#  1   start                               float32
#  2   end                                 float32
#  3   pic_name                            category
#  4   time_str                            category
#  5   DB                                  category
#  6   ID                                  category
#  7   F0final_sma                         float32
#  8   voicingFinalUnclipped_sma           float32
#  9   jitterLocal_sma                     float32
#  10  jitterDDP_sma                       float32
#  11  shimmerLocal_sma                    float32
#  12  logHNR_sma                          float32
#  13  audspec_lengthL1norm_sma            float32
#  14  audspecRasta_lengthL1norm_sma       float32
#  15  pcm_RMSenergy_sma                   float32
#  16  pcm_zcr_sma                         float32
#  17  audSpec_Rfilt_sma[0]                float32
#  18  pcm_fftMag_spectralFlux_sma         float32
#  19  pcm_fftMag_spectralEntropy_sma      float32
#  20  pcm_fftMag_spectralVariance_sma     float32
#  21  pcm_fftMag_spectralHarmonicity_sma  float32
#  22  mfcc_sma[1]                         float32
# dtypes: category(5), float32(18)
# memory usage: 1.3 GB

# %%
df_compare_lld[
    ["file", "start", "end", "pic_name", "time_str", "DB", "ID"] + comp_cols
].to_parquet(loc_data_dir / "df_compare_lld_full_dur.parquet", engine="fastparquet")

# %% [markdown]
# # Varia: Comparing various opensmile configs

# %%
func_egemaps: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)

func_compare: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

lld_gemaps: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)
lld_egemaps: opensmile.Smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# %%
# Gemaps vs. egemaps
print('Functionals')
display(set(func_gemaps.feature_names).difference(set(func_egemaps.feature_names)))
display(set(func_egemaps.feature_names).difference(set(func_gemaps.feature_names)))
print('-'*50)
print("LDDs")
display(set(lld_gemaps.feature_names).difference(set(lld_egemaps.feature_names)))
display(set(lld_egemaps.feature_names).difference(set(lld_gemaps.feature_names)))
# Out:
# Functionals
# set()
# {'F2bandwidth_sma3nz_amean',
#  'F2bandwidth_sma3nz_stddevNorm',
#  'F3bandwidth_sma3nz_amean',
#  'F3bandwidth_sma3nz_stddevNorm',
#  'equivalentSoundLevel_dBp',
#  'mfcc1V_sma3nz_amean',
#  'mfcc1V_sma3nz_stddevNorm',
#  'mfcc1_sma3_amean',
#  'mfcc1_sma3_stddevNorm',
#  'mfcc2V_sma3nz_amean',
#  'mfcc2V_sma3nz_stddevNorm',
#  'mfcc2_sma3_amean',
#  'mfcc2_sma3_stddevNorm',
#  'mfcc3V_sma3nz_amean',
#  'mfcc3V_sma3nz_stddevNorm',
#  'mfcc3_sma3_amean',
#  'mfcc3_sma3_stddevNorm',
#  'mfcc4V_sma3nz_amean',
#  'mfcc4V_sma3nz_stddevNorm',
#  'mfcc4_sma3_amean',
#  'mfcc4_sma3_stddevNorm',
#  'spectralFluxUV_sma3nz_amean',
#  'spectralFluxV_sma3nz_amean',
#  'spectralFluxV_sma3nz_stddevNorm',
#  'spectralFlux_sma3_amean',
#  'spectralFlux_sma3_stddevNorm'}
# --------------------------------------------------
# LDDs
# set()
# {'F2bandwidth_sma3nz',
#  'F3bandwidth_sma3nz',
#  'mfcc1_sma3',
#  'mfcc2_sma3',
#  'mfcc3_sma3',
#  'mfcc4_sma3',
#  'spectralFlux_sma3'}

# %%
# Gemaps vs. Compare
print('Functionals')
display(set(func_gemaps.feature_names).difference(set(func_compare.feature_names)))
display(set(func_compare.feature_names).difference(set(func_gemaps.feature_names)))
print('-'*50)
# Out:
# Functionals
# {'F0semitoneFrom27.5Hz_sma3nz_amean',
#  'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#  'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#  'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#  'F1amplitudeLogRelF0_sma3nz_amean',
#  'F1amplitudeLogRelF0_sma3nz_stddevNorm',
#  'F1bandwidth_sma3nz_amean',
#  'F1bandwidth_sma3nz_stddevNorm',
#  'F1frequency_sma3nz_amean',
#  'F1frequency_sma3nz_stddevNorm',
#  'F2amplitudeLogRelF0_sma3nz_amean',
#  'F2amplitudeLogRelF0_sma3nz_stddevNorm',
#  'F2frequency_sma3nz_amean',
#  'F2frequency_sma3nz_stddevNorm',
#  'F3amplitudeLogRelF0_sma3nz_amean',
#  'F3amplitudeLogRelF0_sma3nz_stddevNorm',
#  'F3frequency_sma3nz_amean',
#  'F3frequency_sma3nz_stddevNorm',
#  'HNRdBACF_sma3nz_amean',
#  'HNRdBACF_sma3nz_stddevNorm',
#  'MeanUnvoicedSegmentLength',
#  'MeanVoicedSegmentLengthSec',
#  'StddevUnvoicedSegmentLength',
#  'StddevVoicedSegmentLengthSec',
#  'VoicedSegmentsPerSec',
#  'alphaRatioUV_sma3nz_amean',
#  'alphaRatioV_sma3nz_amean',
#  'alphaRatioV_sma3nz_stddevNorm',
#  'hammarbergIndexUV_sma3nz_amean',
#  'hammarbergIndexV_sma3nz_amean',
#  'hammarbergIndexV_sma3nz_stddevNorm',
#  'jitterLocal_sma3nz_amean',
#  'jitterLocal_sma3nz_stddevNorm',
#  'logRelF0-H1-A3_sma3nz_amean',
#  'logRelF0-H1-A3_sma3nz_stddevNorm',
#  'logRelF0-H1-H2_sma3nz_amean',
#  'logRelF0-H1-H2_sma3nz_stddevNorm',
#  'loudnessPeaksPerSec',
#  'loudness_sma3_amean',
#  'loudness_sma3_meanFallingSlope',
#  'loudness_sma3_meanRisingSlope',
#  'loudness_sma3_pctlrange0-2',
#  'loudness_sma3_percentile20.0',
#  'loudness_sma3_percentile50.0',
#  'loudness_sma3_percentile80.0',
#  'loudness_sma3_stddevFallingSlope',
#  'loudness_sma3_stddevNorm',
#  'loudness_sma3_stddevRisingSlope',
#  'shimmerLocaldB_sma3nz_amean',
#  'shimmerLocaldB_sma3nz_stddevNorm',
#  'slopeUV0-500_sma3nz_amean',
#  'slopeUV500-1500_sma3nz_amean',
#  'slopeV0-500_sma3nz_amean',
#  'slopeV0-500_sma3nz_stddevNorm',
#  'slopeV500-1500_sma3nz_amean',
#  'slopeV500-1500_sma3nz_stddevNorm'}
# {'audSpec_Rfilt_sma[19]_meanSegLen',
#  'audSpec_Rfilt_sma[8]_rqmean',
#  'pcm_fftMag_spectralKurtosis_sma_de_peakMeanAbs',
#  'audSpec_Rfilt_sma[23]_stddev',
#  'audSpec_Rfilt_sma[6]_stddevFallingSlope',
#  'audSpec_Rfilt_sma_de[8]_minSegLen',
#  'pcm_fftMag_spectralSkewness_sma_de_quartile1',
#  'pcm_fftMag_spectralCentroid_sma_de_upleveltime25',
#  'mfcc_sma_de[6]_meanFallingSlope',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_peakMeanRel',
#  'mfcc_sma_de[13]_lpc2',
#  'audSpec_Rfilt_sma_de[3]_meanPeakDist',
#  'audSpec_Rfilt_sma_de[21]_risetime',
#  'audSpec_Rfilt_sma[9]_iqr1-3',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_percentile99.0',
#  'pcm_fftMag_spectralKurtosis_sma_qregc3',
#  'audSpec_Rfilt_sma[5]_rqmean',
#  'pcm_fftMag_fband1000-4000_sma_quartile2',
#  'mfcc_sma_de[13]_peakDistStddev',
#  'audSpec_Rfilt_sma_de[10]_iqr2-3',
#  'mfcc_sma_de[9]_minPos',
#  'audSpec_Rfilt_sma[14]_upleveltime90',
#  'pcm_fftMag_spectralRollOff25.0_sma_de_lpc4',
#  'pcm_fftMag_spectralSlope_sma_flatness',
#  'pcm_fftMag_spectralHarmonicity_sma_de_quartile3',
#  'mfcc_sma_de[2]_range',
#  'mfcc_sma_de[11]_upleveltime25',
#  'audSpec_Rfilt_sma[16]_upleveltime90',
#  'audSpec_Rfilt_sma[14]_amean',
#  'voicingFinalUnclipped_sma_de_quartile3',
#  'mfcc_sma[12]_quartile1',
#  'audSpec_Rfilt_sma[0]_lpgain',
#  'audSpec_Rfilt_sma[8]_lpc4',
#  'audspec_lengthL1norm_sma_de_iqr1-2',
#  'audSpec_Rfilt_sma[22]_linregc1',
#  'pcm_fftMag_fband250-650_sma_de_kurtosis',
#  'mfcc_sma[10]_upleveltime75',
#  'jitterLocal_sma_de_qregc1',
#  'pcm_fftMag_spectralSlope_sma_meanFallingSlope',
#  'audSpec_Rfilt_sma[19]_lpc2',
#  'voicingFinalUnclipped_sma_iqr1-2',
#  'audspecRasta_lengthL1norm_sma_de_posamean',
#  'mfcc_sma[4]_pctlrange0-1',
#  'F0final_sma_iqr1-2',
#  'audSpec_Rfilt_sma[0]_minPos',
#  'mfcc_sma[8]_quartile3',
#  'audSpec_Rfilt_sma[11]_stddevRisingSlope',
#  'mfcc_sma[9]_percentile1.0',
#  'pcm_fftMag_spectralHarmonicity_sma_de_percentile1.0',
#  'audSpec_Rfilt_sma_de[16]_posamean',
#  'pcm_fftMag_spectralKurtosis_sma_de_stddevRisingSlope',
#  'pcm_fftMag_spectralRollOff25.0_sma_stddevFallingSlope',
#  'pcm_fftMag_fband1000-4000_sma_segLenStddev',
#  'audSpec_Rfilt_sma[21]_linregerrQ',
#  'audSpec_Rfilt_sma_de[1]_peakMeanAbs',
#  'pcm_zcr_sma_de_stddevFallingSlope',
#  'audSpec_Rfilt_sma_de[12]_flatness',
#  'mfcc_sma_de[12]_meanSegLen',
#  'audSpec_Rfilt_sma[22]_qregerrQ',
#  'audSpec_Rfilt_sma[17]_maxPos',
#  'mfcc_sma[7]_stddev',
#  'audSpec_Rfilt_sma_de[14]_iqr1-2',
#  'audSpec_Rfilt_sma[6]_lpc0',
#  'audSpec_Rfilt_sma[13]_flatness',
#  'F0final_sma_de_lpc1',
#  'logHNR_sma_de_percentile99.0',
#  'audSpec_Rfilt_sma_de[24]_peakRangeRel',
#  'mfcc_sma_de[1]_iqr2-3',
#  'mfcc_sma[14]_percentile99.0',
#  'pcm_fftMag_spectralSkewness_sma_de_lpgain',
#  'pcm_fftMag_spectralHarmonicity_sma_risetime',
#  'audSpec_Rfilt_sma_de[15]_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[20]_minPos',
#  'pcm_fftMag_spectralCentroid_sma_minRangeRel',
#  'audSpec_Rfilt_sma[23]_lpc1',
#  'mfcc_sma[3]_linregc2',
#  'audSpec_Rfilt_sma[11]_range',
#  'pcm_fftMag_spectralRollOff25.0_sma_de_skewness',
#  'audSpec_Rfilt_sma_de[0]_quartile3',
#  'pcm_fftMag_spectralSkewness_sma_peakRangeRel',
#  'voicingFinalUnclipped_sma_de_linregc2',
#  'audSpec_Rfilt_sma[5]_linregc2',
#  'pcm_fftMag_spectralSlope_sma_linregc1',
#  'audspec_lengthL1norm_sma_de_segLenStddev',
#  'pcm_fftMag_spectralSlope_sma_de_upleveltime50',
#  'audSpec_Rfilt_sma_de[21]_segLenStddev',
#  'audSpec_Rfilt_sma[9]_flatness',
#  'pcm_fftMag_spectralCentroid_sma_de_lpgain',
#  'audSpec_Rfilt_sma[17]_linregerrQ',
#  'audSpec_Rfilt_sma[2]_iqr1-3',
#  'audSpec_Rfilt_sma_de[8]_minPos',
#  'audSpec_Rfilt_sma[5]_stddev',
#  'audSpec_Rfilt_sma[9]_peakRangeRel',
#  'mfcc_sma[6]_lpgain',
#  'pcm_fftMag_spectralCentroid_sma_de_stddevFallingSlope',
#  'audSpec_Rfilt_sma[2]_risetime',
#  'audSpec_Rfilt_sma[15]_peakRangeRel',
#  'pcm_fftMag_spectralEntropy_sma_amean',
#  'pcm_fftMag_spectralRollOff75.0_sma_de_iqr1-2',
#  'mfcc_sma[10]_upleveltime50',
#  'audSpec_Rfilt_sma_de[24]_lpc1',
#  'audspec_lengthL1norm_sma_de_peakMeanRel',
#  'audSpec_Rfilt_sma_de[18]_percentile99.0',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_stddevRisingSlope',
#  'audSpec_Rfilt_sma_de[0]_maxSegLen',
#  'pcm_fftMag_spectralRollOff25.0_sma_kurtosis',
#  'audspec_lengthL1norm_sma_centroid',
#  'audSpec_Rfilt_sma_de[0]_meanSegLen',
#  'audSpec_Rfilt_sma[16]_lpc4',
#  'pcm_fftMag_spectralRollOff50.0_sma_stddevFallingSlope',
#  'pcm_fftMag_spectralKurtosis_sma_linregc1',
#  'F0final_sma_linregc1',
#  'audSpec_Rfilt_sma[4]_qregerrQ',
#  'pcm_fftMag_spectralKurtosis_sma_de_lpc2',
#  'audSpec_Rfilt_sma[25]_qregc1',
#  'audSpec_Rfilt_sma_de[6]_lpc4',
#  'audspec_lengthL1norm_sma_quartile3',
#  'pcm_fftMag_spectralEntropy_sma_stddevFallingSlope',
#  'pcm_fftMag_spectralHarmonicity_sma_stddev',
#  'pcm_fftMag_spectralCentroid_sma_peakRangeAbs',
#  'pcm_fftMag_spectralSlope_sma_de_meanFallingSlope',
#  'mfcc_sma_de[6]_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[6]_iqr2-3',
#  'mfcc_sma[7]_percentile1.0',
#  'audSpec_Rfilt_sma[13]_lpc4',
#  'shimmerLocal_sma_upleveltime90',
#  'audSpec_Rfilt_sma[1]_linregc1',
#  'audSpec_Rfilt_sma[22]_qregc2',
#  'voicingFinalUnclipped_sma_minPos',
#  'F0final_sma_de_centroid',
#  'audSpec_Rfilt_sma_de[23]_stddev',
#  'audSpec_Rfilt_sma_de[22]_leftctime',
#  'audspec_lengthL1norm_sma_peakMeanAbs',
#  'pcm_fftMag_spectralSlope_sma_peakMeanMeanDist',
#  'audSpec_Rfilt_sma_de[9]_flatness',
#  'mfcc_sma_de[5]_iqr1-2',
#  'mfcc_sma[10]_minSegLen',
#  'audSpec_Rfilt_sma[5]_meanPeakDist',
#  'audSpec_Rfilt_sma_de[3]_quartile3',
#  'mfcc_sma[12]_risetime',
#  'audSpec_Rfilt_sma[13]_maxPos',
#  'logHNR_sma_iqr1-2',
#  'audSpec_Rfilt_sma_de[6]_kurtosis',
#  'audSpec_Rfilt_sma_de[11]_meanRisingSlope',
#  'audSpec_Rfilt_sma[0]_minRangeRel',
#  'mfcc_sma[9]_peakMeanRel',
#  'audspecRasta_lengthL1norm_sma_qregc2',
#  'audSpec_Rfilt_sma_de[17]_skewness',
#  'audSpec_Rfilt_sma_de[25]_stddevRisingSlope',
#  'pcm_fftMag_spectralSkewness_sma_quartile3',
#  'pcm_fftMag_psySharpness_sma_iqr1-3',
#  'audspec_lengthL1norm_sma_linregc1',
#  'audSpec_Rfilt_sma_de[3]_lpc3',
#  'pcm_fftMag_fband1000-4000_sma_de_rqmean',
#  'shimmerLocal_sma_de_leftctime',
#  'audSpec_Rfilt_sma_de[14]_pctlrange0-1',
#  'audSpec_Rfilt_sma[11]_rqmean',
#  'audSpec_Rfilt_sma[12]_percentile99.0',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_peakMeanRel',
#  'voicingFinalUnclipped_sma_linregerrQ',
#  'mfcc_sma[6]_qregc2',
#  'pcm_fftMag_spectralEntropy_sma_minRangeRel',
#  'audSpec_Rfilt_sma_de[24]_range',
#  'audSpec_Rfilt_sma_de[24]_minRangeRel',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_iqr1-2',
#  'pcm_fftMag_spectralRollOff90.0_sma_maxPos',
#  'audSpec_Rfilt_sma[17]_amean',
#  'audSpec_Rfilt_sma[19]_percentile1.0',
#  'pcm_fftMag_spectralRollOff75.0_sma_lpgain',
#  'audSpec_Rfilt_sma_de[15]_lpc0',
#  'audSpec_Rfilt_sma[16]_stddevFallingSlope',
#  'mfcc_sma[12]_minPos',
#  'pcm_fftMag_spectralEntropy_sma_kurtosis',
#  'audSpec_Rfilt_sma[11]_minPos',
#  'audSpec_Rfilt_sma_de[2]_quartile1',
#  'audspec_lengthL1norm_sma_de_stddev',
#  'pcm_zcr_sma_quartile2',
#  'audSpec_Rfilt_sma[23]_maxSegLen',
#  'audSpec_Rfilt_sma[13]_amean',
#  'mfcc_sma[6]_meanRisingSlope',
#  'jitterLocal_sma_lpgain',
#  'audSpec_Rfilt_sma[7]_meanSegLen',
#  'pcm_zcr_sma_linregc1',
#  'mfcc_sma_de[14]_rqmean',
#  'pcm_fftMag_spectralRollOff25.0_sma_de_rqmean',
#  'audspec_lengthL1norm_sma_de_quartile2',
#  'audSpec_Rfilt_sma_de[23]_lpc3',
#  'audSpec_Rfilt_sma[19]_flatness',
#  'pcm_fftMag_spectralSlope_sma_de_rqmean',
#  'audSpec_Rfilt_sma_de[8]_skewness',
#  'pcm_fftMag_spectralRollOff90.0_sma_linregerrQ',
#  'mfcc_sma[6]_meanFallingSlope',
#  'pcm_fftMag_spectralVariance_sma_iqr1-2',
#  'audSpec_Rfilt_sma[21]_minPos',
#  'pcm_fftMag_spectralHarmonicity_sma_de_meanSegLen',
#  'audSpec_Rfilt_sma[5]_segLenStddev',
#  'pcm_fftMag_spectralVariance_sma_de_maxSegLen',
#  'pcm_fftMag_spectralRollOff75.0_sma_flatness',
#  'audSpec_Rfilt_sma[14]_pctlrange0-1',
#  'shimmerLocal_sma_de_lpgain',
#  'pcm_fftMag_spectralFlux_sma_maxPos',
#  'audSpec_Rfilt_sma_de[13]_pctlrange0-1',
#  'audSpec_Rfilt_sma[15]_iqr1-3',
#  'audspecRasta_lengthL1norm_sma_lpc2',
#  'mfcc_sma[7]_leftctime',
#  'mfcc_sma[9]_qregerrQ',
#  'audSpec_Rfilt_sma[24]_linregc1',
#  'pcm_fftMag_spectralSkewness_sma_iqr1-2',
#  'pcm_fftMag_fband250-650_sma_iqr1-2',
#  'audSpec_Rfilt_sma[16]_lpc2',
#  'pcm_RMSenergy_sma_iqr1-2',
#  'audSpec_Rfilt_sma_de[13]_quartile3',
#  'pcm_fftMag_spectralHarmonicity_sma_iqr2-3',
#  'audSpec_Rfilt_sma[23]_range',
#  'audSpec_Rfilt_sma[18]_minRangeRel',
#  'pcm_fftMag_psySharpness_sma_de_peakMeanAbs',
#  'audSpec_Rfilt_sma[3]_rqmean',
#  'pcm_fftMag_spectralEntropy_sma_leftctime',
#  'pcm_fftMag_spectralRollOff75.0_sma_de_minPos',
#  'audSpec_Rfilt_sma[16]_linregc2',
#  'audSpec_Rfilt_sma_de[7]_upleveltime90',
#  'pcm_fftMag_spectralEntropy_sma_lpc4',
#  'F0final_sma_lpc1',
#  'audSpec_Rfilt_sma[21]_peakMeanRel',
#  'audSpec_Rfilt_sma[25]_stddevFallingSlope',
#  'audSpec_Rfilt_sma[25]_risetime',
#  'audSpec_Rfilt_sma[12]_peakMeanAbs',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_stddevRisingSlope',
#  'pcm_fftMag_spectralEntropy_sma_linregc2',
#  'mfcc_sma[6]_stddev',
#  'audSpec_Rfilt_sma[16]_lpc0',
#  'mfcc_sma_de[4]_percentile1.0',
#  'mfcc_sma_de[9]_peakDistStddev',
#  'audSpec_Rfilt_sma[18]_percentile99.0',
#  'audSpec_Rfilt_sma_de[10]_upleveltime75',
#  'audSpec_Rfilt_sma[1]_linregerrQ',
#  'audspecRasta_lengthL1norm_sma_iqr2-3',
#  'audSpec_Rfilt_sma[10]_iqr2-3',
#  'mfcc_sma[9]_segLenStddev',
#  'jitterLocal_sma_de_risetime',
#  'audSpec_Rfilt_sma[13]_meanRisingSlope',
#  'audSpec_Rfilt_sma[20]_quartile1',
#  'audSpec_Rfilt_sma[18]_kurtosis',
#  'mfcc_sma[5]_minRangeRel',
#  'audSpec_Rfilt_sma[4]_lpgain',
#  'pcm_fftMag_fband1000-4000_sma_pctlrange0-1',
#  'mfcc_sma[14]_linregc2',
#  'audspecRasta_lengthL1norm_sma_upleveltime25',
#  'mfcc_sma[2]_qregerrQ',
#  'audSpec_Rfilt_sma_de[15]_quartile3',
#  'audSpec_Rfilt_sma[12]_segLenStddev',
#  'pcm_fftMag_spectralRollOff25.0_sma_lpc0',
#  'audSpec_Rfilt_sma_de[11]_iqr1-3',
#  'pcm_fftMag_spectralSkewness_sma_de_pctlrange0-1',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_leftctime',
#  'audSpec_Rfilt_sma_de[17]_meanSegLen',
#  'audSpec_Rfilt_sma[4]_maxSegLen',
#  'mfcc_sma_de[5]_stddev',
#  'pcm_fftMag_spectralRollOff25.0_sma_upleveltime25',
#  'pcm_fftMag_spectralCentroid_sma_de_iqr2-3',
#  'pcm_fftMag_spectralCentroid_sma_lpc0',
#  'mfcc_sma_de[13]_pctlrange0-1',
#  'mfcc_sma[6]_qregc1',
#  'mfcc_sma_de[12]_peakMeanMeanDist',
#  'mfcc_sma_de[3]_meanSegLen',
#  'pcm_fftMag_fband250-650_sma_linregerrQ',
#  'audSpec_Rfilt_sma[17]_linregc2',
#  'audSpec_Rfilt_sma_de[2]_lpc4',
#  'mfcc_sma_de[12]_meanRisingSlope',
#  'audSpec_Rfilt_sma_de[0]_lpc0',
#  'audSpec_Rfilt_sma_de[16]_meanFallingSlope',
#  'audSpec_Rfilt_sma_de[16]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma_de[21]_iqr1-2',
#  'pcm_RMSenergy_sma_range',
#  'pcm_fftMag_spectralSlope_sma_upleveltime75',
#  'audSpec_Rfilt_sma_de[0]_skewness',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_posamean',
#  'audSpec_Rfilt_sma[3]_stddev',
#  'pcm_fftMag_spectralVariance_sma_leftctime',
#  'mfcc_sma[5]_peakRangeRel',
#  'audSpec_Rfilt_sma_de[3]_minRangeRel',
#  'audSpec_Rfilt_sma_de[12]_minSegLen',
#  'audspec_lengthL1norm_sma_percentile99.0',
#  'pcm_zcr_sma_de_minSegLen',
#  'pcm_fftMag_spectralRollOff90.0_sma_linregc1',
#  'mfcc_sma_de[4]_meanPeakDist',
#  'pcm_fftMag_spectralKurtosis_sma_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[0]_maxPos',
#  'mfcc_sma[1]_percentile99.0',
#  'audSpec_Rfilt_sma_de[23]_lpc2',
#  'audSpec_Rfilt_sma_de[9]_stddev',
#  'audSpec_Rfilt_sma_de[11]_rqmean',
#  'mfcc_sma[4]_percentile99.0',
#  'pcm_fftMag_spectralHarmonicity_sma_de_peakMeanRel',
#  'logHNR_sma_upleveltime50',
#  'pcm_fftMag_spectralFlux_sma_de_quartile2',
#  'audSpec_Rfilt_sma[1]_qregc3',
#  'pcm_fftMag_spectralRollOff75.0_sma_range',
#  'pcm_fftMag_spectralRollOff25.0_sma_quartile3',
#  'mfcc_sma_de[10]_percentile1.0',
#  'pcm_fftMag_spectralKurtosis_sma_de_upleveltime75',
#  'mfcc_sma_de[9]_lpc4',
#  'mfcc_sma_de[4]_iqr1-3',
#  'audSpec_Rfilt_sma[10]_lpc1',
#  'audspecRasta_lengthL1norm_sma_de_minPos',
#  'pcm_fftMag_spectralEntropy_sma_de_lpc4',
#  'audSpec_Rfilt_sma_de[2]_peakRangeAbs',
#  'audSpec_Rfilt_sma[16]_maxPos',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_maxPos',
#  'audSpec_Rfilt_sma[8]_linregerrQ',
#  'audSpec_Rfilt_sma[9]_rqmean',
#  'audSpec_Rfilt_sma[23]_rqmean',
#  'mfcc_sma[9]_maxSegLen',
#  'audSpec_Rfilt_sma[9]_maxSegLen',
#  'F0final_sma_de_qregerrQ',
#  'pcm_fftMag_fband250-650_sma_de_stddevRisingSlope',
#  'pcm_fftMag_spectralCentroid_sma_de_rqmean',
#  'mfcc_sma[7]_qregc3',
#  'mfcc_sma[6]_stddevFallingSlope',
#  'audSpec_Rfilt_sma_de[4]_percentile1.0',
#  'audSpec_Rfilt_sma_de[9]_upleveltime25',
#  'audSpec_Rfilt_sma_de[6]_percentile99.0',
#  'pcm_fftMag_psySharpness_sma_peakMeanRel',
#  'audSpec_Rfilt_sma[25]_rqmean',
#  'mfcc_sma[11]_minSegLen',
#  'mfcc_sma[6]_iqr1-2',
#  'pcm_fftMag_spectralKurtosis_sma_de_peakRangeRel',
#  'mfcc_sma[1]_lpc4',
#  'pcm_RMSenergy_sma_de_iqr2-3',
#  'audspec_lengthL1norm_sma_de_lpc3',
#  'pcm_fftMag_spectralSlope_sma_de_lpc2',
#  'pcm_fftMag_spectralFlux_sma_de_upleveltime25',
#  'audspecRasta_lengthL1norm_sma_stddevRisingSlope',
#  'mfcc_sma[11]_qregerrQ',
#  'mfcc_sma_de[10]_peakRangeRel',
#  'pcm_fftMag_spectralEntropy_sma_de_upleveltime75',
#  'pcm_fftMag_spectralRollOff50.0_sma_lpc0',
#  'pcm_fftMag_spectralVariance_sma_de_quartile2',
#  'audSpec_Rfilt_sma[22]_amean',
#  'audspecRasta_lengthL1norm_sma_skewness',
#  'audSpec_Rfilt_sma[12]_qregc1',
#  'mfcc_sma_de[3]_posamean',
#  'pcm_fftMag_fband250-650_sma_quartile1',
#  'mfcc_sma[9]_skewness',
#  'audSpec_Rfilt_sma_de[7]_meanFallingSlope',
#  'audspec_lengthL1norm_sma_de_meanPeakDist',
#  'audSpec_Rfilt_sma_de[2]_lpc0',
#  'audSpec_Rfilt_sma[19]_quartile3',
#  'audSpec_Rfilt_sma[19]_amean',
#  'audSpec_Rfilt_sma[14]_stddevRisingSlope',
#  'pcm_fftMag_fband250-650_sma_minPos',
#  'pcm_fftMag_psySharpness_sma_qregerrQ',
#  'audSpec_Rfilt_sma[4]_peakDistStddev',
#  'pcm_fftMag_spectralRollOff25.0_sma_de_peakMeanMeanDist',
#  'mfcc_sma[5]_qregc3',
#  'F0final_sma_leftctime',
#  'audSpec_Rfilt_sma_de[22]_quartile2',
#  'pcm_zcr_sma_leftctime',
#  'pcm_fftMag_fband250-650_sma_flatness',
#  'audSpec_Rfilt_sma[17]_iqr1-3',
#  'audSpec_Rfilt_sma_de[0]_quartile1',
#  'audSpec_Rfilt_sma_de[15]_maxPos',
#  'audSpec_Rfilt_sma_de[13]_peakDistStddev',
#  'mfcc_sma_de[8]_stddev',
#  'pcm_fftMag_spectralFlux_sma_de_lpc4',
#  'audSpec_Rfilt_sma_de[23]_quartile1',
#  'pcm_fftMag_spectralFlux_sma_linregerrQ',
#  'mfcc_sma[9]_stddevRisingSlope',
#  'mfcc_sma[3]_lpgain',
#  'audSpec_Rfilt_sma[5]_lpc1',
#  'audSpec_Rfilt_sma_de[10]_stddevFallingSlope',
#  'pcm_fftMag_spectralEntropy_sma_de_lpgain',
#  'mfcc_sma_de[14]_stddevRisingSlope',
#  'audSpec_Rfilt_sma[12]_lpc3',
#  'mfcc_sma[2]_linregc1',
#  'audSpec_Rfilt_sma[3]_amean',
#  'mfcc_sma_de[10]_meanPeakDist',
#  'audSpec_Rfilt_sma[19]_qregc2',
#  'audSpec_Rfilt_sma_de[12]_risetime',
#  'audSpec_Rfilt_sma[19]_quartile2',
#  'pcm_fftMag_spectralFlux_sma_de_peakRangeRel',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_stddevFallingSlope',
#  'pcm_zcr_sma_de_pctlrange0-1',
#  'pcm_fftMag_spectralKurtosis_sma_de_kurtosis',
#  'audSpec_Rfilt_sma[25]_stddev',
#  'audSpec_Rfilt_sma_de[8]_quartile1',
#  'mfcc_sma_de[2]_stddevRisingSlope',
#  'pcm_fftMag_spectralSlope_sma_minRangeRel',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_flatness',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_lpc2',
#  'audSpec_Rfilt_sma_de[9]_percentile99.0',
#  'audSpec_Rfilt_sma[1]_lpc0',
#  'pcm_RMSenergy_sma_de_meanSegLen',
#  'audSpec_Rfilt_sma[20]_upleveltime75',
#  'mfcc_sma[2]_minPos',
#  'audSpec_Rfilt_sma[1]_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[21]_upleveltime25',
#  'audSpec_Rfilt_sma_de[21]_peakRangeRel',
#  'pcm_fftMag_spectralEntropy_sma_flatness',
#  'pcm_fftMag_fband1000-4000_sma_upleveltime90',
#  'pcm_fftMag_spectralKurtosis_sma_de_maxPos',
#  'pcm_fftMag_spectralFlux_sma_percentile1.0',
#  'mfcc_sma[5]_stddev',
#  'audSpec_Rfilt_sma_de[14]_rqmean',
#  'audSpec_Rfilt_sma_de[3]_peakMeanRel',
#  'audSpec_Rfilt_sma_de[24]_lpc0',
#  'mfcc_sma_de[12]_peakMeanAbs',
#  'mfcc_sma[2]_lpc0',
#  'mfcc_sma[8]_qregerrQ',
#  'mfcc_sma[3]_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[3]_peakMeanMeanDist',
#  'shimmerLocal_sma_lpc1',
#  'audSpec_Rfilt_sma_de[7]_peakRangeAbs',
#  'jitterLocal_sma_qregc1',
#  'pcm_fftMag_spectralFlux_sma_meanFallingSlope',
#  'audSpec_Rfilt_sma_de[22]_minSegLen',
#  'audSpec_Rfilt_sma_de[1]_maxPos',
#  'pcm_fftMag_spectralRollOff90.0_sma_iqr1-3',
#  'mfcc_sma[2]_stddevFallingSlope',
#  'pcm_fftMag_spectralSlope_sma_minPos',
#  'mfcc_sma[12]_lpc0',
#  'pcm_fftMag_spectralRollOff75.0_sma_minRangeRel',
#  'audSpec_Rfilt_sma_de[13]_peakRangeRel',
#  'audSpec_Rfilt_sma_de[7]_meanSegLen',
#  'mfcc_sma_de[1]_range',
#  'mfcc_sma[3]_iqr2-3',
#  'F0final_sma_lpc0',
#  'audSpec_Rfilt_sma[22]_qregc3',
#  'audSpec_Rfilt_sma_de[10]_lpc1',
#  'pcm_fftMag_spectralSkewness_sma_lpc4',
#  'mfcc_sma_de[9]_peakMeanAbs',
#  'audSpec_Rfilt_sma[20]_lpc2',
#  'mfcc_sma_de[1]_meanFallingSlope',
#  'pcm_fftMag_spectralCentroid_sma_iqr1-3',
#  'audSpec_Rfilt_sma_de[13]_quartile1',
#  'mfcc_sma[8]_upleveltime90',
#  'mfcc_sma_de[10]_meanSegLen',
#  'jitterLocal_sma_linregc1',
#  'audSpec_Rfilt_sma[1]_leftctime',
#  'mfcc_sma[14]_peakMeanMeanDist',
#  'pcm_fftMag_fband1000-4000_sma_qregc3',
#  'audSpec_Rfilt_sma_de[11]_percentile1.0',
#  'audSpec_Rfilt_sma_de[11]_iqr2-3',
#  'audSpec_Rfilt_sma[18]_qregc3',
#  'audSpec_Rfilt_sma_de[19]_peakMeanMeanDist',
#  'pcm_fftMag_fband1000-4000_sma_de_peakMeanAbs',
#  'audSpec_Rfilt_sma[15]_iqr2-3',
#  'mfcc_sma[6]_kurtosis',
#  'audSpec_Rfilt_sma_de[24]_stddevFallingSlope',
#  'audSpec_Rfilt_sma_de[9]_stddevFallingSlope',
#  'audSpec_Rfilt_sma[16]_quartile2',
#  'pcm_fftMag_spectralRollOff75.0_sma_de_peakDistStddev',
#  'audSpec_Rfilt_sma[11]_iqr2-3',
#  'mfcc_sma[8]_iqr1-2',
#  'pcm_fftMag_psySharpness_sma_minPos',
#  'audSpec_Rfilt_sma[4]_upleveltime75',
#  'audSpec_Rfilt_sma[15]_risetime',
#  'audspecRasta_lengthL1norm_sma_meanPeakDist',
#  'pcm_RMSenergy_sma_linregc2',
#  'audSpec_Rfilt_sma[9]_stddevFallingSlope',
#  'mfcc_sma[8]_peakRangeAbs',
#  'mfcc_sma[3]_lpc1',
#  'audSpec_Rfilt_sma_de[11]_stddevRisingSlope',
#  'audSpec_Rfilt_sma_de[8]_iqr2-3',
#  'audSpec_Rfilt_sma_de[22]_upleveltime25',
#  'audSpec_Rfilt_sma_de[25]_upleveltime50',
#  'pcm_fftMag_psySharpness_sma_de_upleveltime25',
#  'mfcc_sma_de[13]_stddevFallingSlope',
#  'audspecRasta_lengthL1norm_sma_de_quartile2',
#  'audSpec_Rfilt_sma[4]_percentile99.0',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_peakMeanMeanDist',
#  'audSpec_Rfilt_sma[17]_peakDistStddev',
#  'audSpec_Rfilt_sma_de[8]_peakMeanAbs',
#  'mfcc_sma[12]_linregc2',
#  'pcm_fftMag_psySharpness_sma_iqr2-3',
#  'pcm_fftMag_fband250-650_sma_de_upleveltime75',
#  'pcm_fftMag_spectralKurtosis_sma_de_lpc1',
#  'audSpec_Rfilt_sma[7]_peakDistStddev',
#  'mfcc_sma_de[4]_upleveltime50',
#  'pcm_fftMag_spectralCentroid_sma_qregc2',
#  'audSpec_Rfilt_sma_de[17]_lpgain',
#  'mfcc_sma[3]_amean',
#  'mfcc_sma[10]_meanRisingSlope',
#  'pcm_fftMag_spectralHarmonicity_sma_de_range',
#  'mfcc_sma[14]_minSegLen',
#  'audSpec_Rfilt_sma[19]_lpgain',
#  'audSpec_Rfilt_sma_de[8]_quartile2',
#  'mfcc_sma_de[8]_upleveltime50',
#  'pcm_fftMag_psySharpness_sma_upleveltime50',
#  'audspecRasta_lengthL1norm_sma_risetime',
#  'audSpec_Rfilt_sma[7]_upleveltime50',
#  'audSpec_Rfilt_sma[13]_meanFallingSlope',
#  'mfcc_sma[1]_peakMeanRel',
#  'pcm_fftMag_spectralRollOff90.0_sma_upleveltime75',
#  'audspec_lengthL1norm_sma_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[13]_meanPeakDist',
#  'pcm_fftMag_spectralFlux_sma_kurtosis',
#  'audspec_lengthL1norm_sma_de_upleveltime75',
#  'mfcc_sma[5]_peakMeanMeanDist',
#  'pcm_fftMag_spectralRollOff75.0_sma_skewness',
#  'mfcc_sma_de[11]_risetime',
#  'audSpec_Rfilt_sma_de[19]_pctlrange0-1',
#  'audSpec_Rfilt_sma_de[16]_upleveltime90',
#  'F0final_sma_range',
#  'logHNR_sma_de_qregc3',
#  'mfcc_sma_de[7]_lpc0',
#  'audSpec_Rfilt_sma_de[10]_iqr1-3',
#  'mfcc_sma_de[2]_percentile1.0',
#  'mfcc_sma[8]_percentile1.0',
#  'pcm_fftMag_spectralRollOff75.0_sma_iqr1-2',
#  'audSpec_Rfilt_sma_de[2]_kurtosis',
#  'audSpec_Rfilt_sma_de[3]_stddev',
#  'pcm_fftMag_spectralCentroid_sma_linregerrQ',
#  'audSpec_Rfilt_sma_de[10]_minSegLen',
#  'mfcc_sma[13]_lpc2',
#  'pcm_fftMag_spectralRollOff90.0_sma_segLenStddev',
#  'audspecRasta_lengthL1norm_sma_meanRisingSlope',
#  'audSpec_Rfilt_sma[15]_meanPeakDist',
#  'pcm_fftMag_fband1000-4000_sma_linregc1',
#  'audSpec_Rfilt_sma_de[14]_peakMeanAbs',
#  'pcm_fftMag_fband250-650_sma_de_flatness',
#  'audSpec_Rfilt_sma[6]_meanRisingSlope',
#  'audSpec_Rfilt_sma[19]_linregc1',
#  'audSpec_Rfilt_sma_de[14]_iqr1-3',
#  'mfcc_sma[7]_upleveltime50',
#  'audSpec_Rfilt_sma[11]_percentile1.0',
#  'audSpec_Rfilt_sma[19]_maxPos',
#  'jitterLocal_sma_stddev',
#  'pcm_fftMag_spectralSlope_sma_de_peakMeanAbs',
#  'pcm_fftMag_spectralSkewness_sma_pctlrange0-1',
#  'mfcc_sma[7]_lpc0',
#  'mfcc_sma[14]_percentile1.0',
#  'pcm_fftMag_fband250-650_sma_de_maxPos',
#  'mfcc_sma_de[5]_minSegLen',
#  'audSpec_Rfilt_sma[2]_upleveltime75',
#  'shimmerLocal_sma_leftctime',
#  'pcm_RMSenergy_sma_de_segLenStddev',
#  'mfcc_sma_de[8]_peakRangeRel',
#  'pcm_fftMag_spectralRollOff90.0_sma_range',
#  'pcm_fftMag_spectralVariance_sma_linregc2',
#  'audSpec_Rfilt_sma[15]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma[0]_peakRangeAbs',
#  'mfcc_sma_de[7]_peakRangeAbs',
#  'mfcc_sma_de[8]_stddevFallingSlope',
#  'pcm_fftMag_spectralKurtosis_sma_quartile1',
#  'mfcc_sma[1]_skewness',
#  'audSpec_Rfilt_sma_de[11]_upleveltime50',
#  'logHNR_sma_de_qregc2',
#  'audSpec_Rfilt_sma_de[18]_rqmean',
#  'audSpec_Rfilt_sma[22]_iqr1-3',
#  'pcm_fftMag_spectralRollOff25.0_sma_quartile2',
#  'mfcc_sma[3]_quartile2',
#  'mfcc_sma[9]_linregc1',
#  'pcm_fftMag_fband1000-4000_sma_centroid',
#  'audSpec_Rfilt_sma_de[3]_risetime',
#  'audSpec_Rfilt_sma_de[16]_lpc0',
#  'mfcc_sma[2]_percentile1.0',
#  'mfcc_sma[7]_lpc4',
#  'pcm_fftMag_psySharpness_sma_upleveltime25',
#  'mfcc_sma_de[6]_segLenStddev',
#  'voicingFinalUnclipped_sma_de_range',
#  'mfcc_sma[3]_peakMeanMeanDist',
#  'mfcc_sma[14]_maxPos',
#  'mfcc_sma_de[5]_peakDistStddev',
#  'audspecRasta_lengthL1norm_sma_de_quartile3',
#  'audSpec_Rfilt_sma_de[1]_iqr1-3',
#  'audSpec_Rfilt_sma_de[11]_upleveltime25',
#  'audSpec_Rfilt_sma[7]_meanFallingSlope',
#  'mfcc_sma[13]_stddev',
#  'audSpec_Rfilt_sma[1]_risetime',
#  'jitterDDP_sma_lpc3',
#  'pcm_zcr_sma_de_upleveltime75',
#  'audSpec_Rfilt_sma[10]_minSegLen',
#  'mfcc_sma_de[3]_lpc1',
#  'audSpec_Rfilt_sma_de[1]_minSegLen',
#  'mfcc_sma[10]_minRangeRel',
#  'audSpec_Rfilt_sma_de[4]_meanSegLen',
#  'audSpec_Rfilt_sma_de[3]_kurtosis',
#  'pcm_fftMag_spectralHarmonicity_sma_de_minRangeRel',
#  'mfcc_sma_de[3]_peakRangeRel',
#  'audSpec_Rfilt_sma[14]_peakMeanAbs',
#  'pcm_RMSenergy_sma_peakDistStddev',
#  'audSpec_Rfilt_sma_de[10]_upleveltime25',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_rqmean',
#  'mfcc_sma[13]_quartile1',
#  'jitterDDP_sma_percentile99.0',
#  'audSpec_Rfilt_sma_de[22]_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[21]_maxPos',
#  'mfcc_sma_de[1]_stddevFallingSlope',
#  'pcm_fftMag_spectralSkewness_sma_stddevFallingSlope',
#  'pcm_fftMag_spectralRollOff90.0_sma_quartile2',
#  'mfcc_sma_de[8]_meanSegLen',
#  'pcm_zcr_sma_de_quartile1',
#  'pcm_fftMag_spectralSlope_sma_de_range',
#  'pcm_RMSenergy_sma_de_upleveltime75',
#  'mfcc_sma[11]_upleveltime50',
#  'pcm_fftMag_spectralRollOff25.0_sma_de_maxPos',
#  'pcm_fftMag_fband250-650_sma_de_leftctime',
#  'mfcc_sma_de[1]_peakMeanAbs',
#  'pcm_fftMag_spectralFlux_sma_de_stddevRisingSlope',
#  'shimmerLocal_sma_de_pctlrange0-1',
#  'audSpec_Rfilt_sma_de[22]_range',
#  'audSpec_Rfilt_sma_de[0]_iqr2-3',
#  'pcm_zcr_sma_linregerrQ',
#  'pcm_fftMag_spectralHarmonicity_sma_percentile99.0',
#  'jitterDDP_sma_kurtosis',
#  'audSpec_Rfilt_sma[19]_upleveltime90',
#  'mfcc_sma_de[6]_lpc1',
#  'audSpec_Rfilt_sma[2]_quartile3',
#  'audspecRasta_lengthL1norm_sma_de_peakRangeAbs',
#  'pcm_fftMag_spectralEntropy_sma_peakMeanAbs',
#  'audSpec_Rfilt_sma[23]_stddevRisingSlope',
#  'audSpec_Rfilt_sma_de[4]_stddev',
#  'mfcc_sma[14]_peakMeanRel',
#  'mfcc_sma_de[14]_peakMeanRel',
#  'mfcc_sma[3]_pctlrange0-1',
#  'pcm_zcr_sma_de_posamean',
#  'audSpec_Rfilt_sma_de[17]_peakMeanMeanDist',
#  'pcm_fftMag_spectralRollOff50.0_sma_maxSegLen',
#  'mfcc_sma_de[5]_kurtosis',
#  'audSpec_Rfilt_sma_de[4]_upleveltime90',
#  'pcm_fftMag_spectralFlux_sma_de_lpc2',
#  'audSpec_Rfilt_sma_de[22]_iqr2-3',
#  'audSpec_Rfilt_sma_de[18]_peakDistStddev',
#  'pcm_fftMag_fband1000-4000_sma_qregc2',
#  'audSpec_Rfilt_sma[0]_linregc2',
#  'audSpec_Rfilt_sma[3]_iqr1-2',
#  'mfcc_sma[9]_iqr2-3',
#  'pcm_fftMag_spectralSkewness_sma_meanSegLen',
#  'mfcc_sma_de[9]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma_de[0]_lpc1',
#  'audSpec_Rfilt_sma_de[25]_lpgain',
#  'pcm_fftMag_spectralSlope_sma_pctlrange0-1',
#  'mfcc_sma[1]_iqr1-3',
#  'shimmerLocal_sma_de_iqr1-2',
#  'audSpec_Rfilt_sma_de[10]_peakDistStddev',
#  'jitterDDP_sma_pctlrange0-1',
#  'audSpec_Rfilt_sma[2]_percentile99.0',
#  'audSpec_Rfilt_sma[19]_skewness',
#  'audSpec_Rfilt_sma_de[19]_peakMeanRel',
#  'mfcc_sma_de[11]_leftctime',
#  'audSpec_Rfilt_sma[12]_maxSegLen',
#  'pcm_fftMag_spectralRollOff90.0_sma_meanFallingSlope',
#  'audSpec_Rfilt_sma[17]_linregc1',
#  'audSpec_Rfilt_sma[18]_upleveltime90',
#  'pcm_fftMag_spectralRollOff90.0_sma_peakRangeAbs',
#  'mfcc_sma_de[6]_posamean',
#  'audSpec_Rfilt_sma[20]_percentile99.0',
#  'mfcc_sma[11]_lpc0',
#  'pcm_RMSenergy_sma_de_percentile99.0',
#  'audSpec_Rfilt_sma[2]_qregc2',
#  'audSpec_Rfilt_sma_de[1]_iqr1-2',
#  'audspecRasta_lengthL1norm_sma_de_maxSegLen',
#  'pcm_fftMag_fband1000-4000_sma_lpc3',
#  'mfcc_sma[2]_maxSegLen',
#  'pcm_fftMag_spectralSkewness_sma_de_lpc2',
#  'audSpec_Rfilt_sma[20]_qregerrQ',
#  'audSpec_Rfilt_sma_de[20]_meanPeakDist',
#  'logHNR_sma_amean',
#  'mfcc_sma[12]_lpc2',
#  'mfcc_sma[8]_amean',
#  'pcm_zcr_sma_de_iqr1-3',
#  'pcm_fftMag_spectralVariance_sma_de_peakDistStddev',
#  'mfcc_sma[9]_stddev',
#  'audSpec_Rfilt_sma[11]_stddevFallingSlope',
#  'pcm_fftMag_spectralSkewness_sma_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[25]_percentile1.0',
#  'mfcc_sma_de[5]_stddevRisingSlope',
#  'audSpec_Rfilt_sma[17]_meanPeakDist',
#  'audSpec_Rfilt_sma[23]_lpc4',
#  'mfcc_sma[2]_iqr1-2',
#  'mfcc_sma_de[5]_range',
#  'audSpec_Rfilt_sma[20]_meanFallingSlope',
#  'pcm_fftMag_spectralKurtosis_sma_meanRisingSlope',
#  'pcm_fftMag_spectralEntropy_sma_de_segLenStddev',
#  'pcm_RMSenergy_sma_de_upleveltime25',
#  'audSpec_Rfilt_sma[24]_qregerrQ',
#  'audSpec_Rfilt_sma_de[12]_lpgain',
#  'pcm_fftMag_spectralRollOff90.0_sma_lpc3',
#  'audSpec_Rfilt_sma[0]_meanRisingSlope',
#  'audSpec_Rfilt_sma[8]_linregc2',
#  'mfcc_sma_de[7]_upleveltime50',
#  'audSpec_Rfilt_sma_de[0]_stddev',
#  'mfcc_sma_de[8]_minSegLen',
#  'mfcc_sma[3]_minRangeRel',
#  'pcm_fftMag_spectralFlux_sma_qregc2',
#  'audspec_lengthL1norm_sma_peakDistStddev',
#  'audSpec_Rfilt_sma[22]_range',
#  'audSpec_Rfilt_sma[8]_kurtosis',
#  'audSpec_Rfilt_sma_de[21]_upleveltime90',
#  'pcm_fftMag_spectralEntropy_sma_linregerrQ',
#  'audSpec_Rfilt_sma[15]_minSegLen',
#  'pcm_fftMag_fband250-650_sma_stddevFallingSlope',
#  'audSpec_Rfilt_sma[25]_range',
#  'audSpec_Rfilt_sma_de[24]_flatness',
#  'audSpec_Rfilt_sma[17]_lpc2',
#  'pcm_fftMag_spectralFlux_sma_meanSegLen',
#  'voicingFinalUnclipped_sma_de_linregerrQ',
#  'mfcc_sma_de[7]_skewness',
#  'mfcc_sma[12]_minRangeRel',
#  'audSpec_Rfilt_sma[5]_range',
#  'audspecRasta_lengthL1norm_sma_de_iqr1-3',
#  'audSpec_Rfilt_sma_de[17]_kurtosis',
#  'audSpec_Rfilt_sma[21]_amean',
#  'audSpec_Rfilt_sma_de[8]_maxSegLen',
#  'pcm_fftMag_fband1000-4000_sma_upleveltime25',
#  'pcm_fftMag_spectralRollOff25.0_sma_meanRisingSlope',
#  'mfcc_sma_de[9]_iqr2-3',
#  'mfcc_sma_de[4]_upleveltime90',
#  'audSpec_Rfilt_sma[12]_linregc2',
#  'mfcc_sma[9]_lpc3',
#  'pcm_RMSenergy_sma_peakMeanRel',
#  'audSpec_Rfilt_sma_de[22]_minPos',
#  'pcm_fftMag_spectralKurtosis_sma_de_quartile2',
#  'audSpec_Rfilt_sma[24]_minRangeRel',
#  'audSpec_Rfilt_sma_de[4]_leftctime',
#  'pcm_fftMag_spectralRollOff75.0_sma_stddevFallingSlope',
#  'pcm_fftMag_spectralHarmonicity_sma_stddevRisingSlope',
#  'audSpec_Rfilt_sma_de[2]_percentile99.0',
#  'audSpec_Rfilt_sma_de[12]_quartile2',
#  'audSpec_Rfilt_sma[6]_stddevRisingSlope',
#  'mfcc_sma[6]_peakMeanMeanDist',
#  'mfcc_sma_de[3]_lpc4',
#  'audSpec_Rfilt_sma[3]_upleveltime75',
#  'audSpec_Rfilt_sma[7]_qregc3',
#  'pcm_fftMag_spectralSkewness_sma_quartile1',
#  'mfcc_sma[11]_quartile2',
#  'pcm_fftMag_spectralEntropy_sma_de_percentile99.0',
#  'audSpec_Rfilt_sma[10]_stddevRisingSlope',
#  'mfcc_sma_de[8]_minPos',
#  'audSpec_Rfilt_sma_de[11]_quartile1',
#  'pcm_fftMag_spectralRollOff25.0_sma_leftctime',
#  'jitterDDP_sma_de_amean',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_lpgain',
#  'audSpec_Rfilt_sma[12]_lpc4',
#  'mfcc_sma[5]_pctlrange0-1',
#  'audSpec_Rfilt_sma[2]_lpc0',
#  'pcm_fftMag_psySharpness_sma_de_maxPos',
#  'pcm_fftMag_fband1000-4000_sma_maxSegLen',
#  'audSpec_Rfilt_sma_de[15]_rqmean',
#  'pcm_zcr_sma_qregc1',
#  'mfcc_sma[9]_lpc0',
#  'voicingFinalUnclipped_sma_de_kurtosis',
#  'pcm_RMSenergy_sma_de_maxPos',
#  'pcm_fftMag_spectralRollOff90.0_sma_pctlrange0-1',
#  'pcm_fftMag_spectralHarmonicity_sma_leftctime',
#  'mfcc_sma[10]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma_de[20]_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[15]_quartile2',
#  'pcm_fftMag_spectralSlope_sma_leftctime',
#  'audSpec_Rfilt_sma[2]_minPos',
#  'pcm_fftMag_spectralVariance_sma_de_lpc3',
#  'audSpec_Rfilt_sma[9]_peakMeanAbs',
#  'mfcc_sma[4]_minSegLen',
#  'mfcc_sma[14]_amean',
#  'mfcc_sma[4]_upleveltime25',
#  'audSpec_Rfilt_sma_de[5]_flatness',
#  'pcm_fftMag_spectralSlope_sma_maxPos',
#  'pcm_fftMag_spectralSkewness_sma_de_iqr1-3',
#  'mfcc_sma_de[1]_quartile2',
#  'pcm_fftMag_spectralSkewness_sma_de_minRangeRel',
#  'pcm_fftMag_fband1000-4000_sma_de_meanSegLen',
#  'mfcc_sma_de[6]_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[18]_upleveltime90',
#  'audSpec_Rfilt_sma_de[20]_segLenStddev',
#  'audSpec_Rfilt_sma_de[23]_meanRisingSlope',
#  'audSpec_Rfilt_sma[7]_peakRangeRel',
#  'mfcc_sma_de[10]_peakMeanRel',
#  'mfcc_sma[1]_stddev',
#  'audSpec_Rfilt_sma[13]_leftctime',
#  'logHNR_sma_minPos',
#  'F0final_sma_de_risetime',
#  'pcm_zcr_sma_flatness',
#  'mfcc_sma[14]_stddevFallingSlope',
#  'audSpec_Rfilt_sma[17]_quartile2',
#  'mfcc_sma_de[8]_lpc3',
#  'mfcc_sma[1]_qregc2',
#  'audSpec_Rfilt_sma_de[9]_minPos',
#  'audSpec_Rfilt_sma[19]_maxSegLen',
#  'shimmerLocal_sma_linregc2',
#  'pcm_fftMag_spectralEntropy_sma_maxPos',
#  'pcm_fftMag_spectralSlope_sma_amean',
#  'mfcc_sma_de[14]_leftctime',
#  'pcm_fftMag_spectralCentroid_sma_de_quartile3',
#  'mfcc_sma[8]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma[12]_qregerrQ',
#  'mfcc_sma_de[10]_upleveltime25',
#  'pcm_zcr_sma_de_maxPos',
#  'audSpec_Rfilt_sma[15]_upleveltime50',
#  'pcm_zcr_sma_iqr1-2',
#  'F0final_sma_de_quartile3',
#  'pcm_fftMag_psySharpness_sma_skewness',
#  'pcm_fftMag_psySharpness_sma_de_minRangeRel',
#  'mfcc_sma[7]_amean',
#  'mfcc_sma[13]_flatness',
#  'pcm_fftMag_fband1000-4000_sma_de_kurtosis',
#  'audSpec_Rfilt_sma[12]_upleveltime75',
#  'mfcc_sma[13]_stddevRisingSlope',
#  'audSpec_Rfilt_sma_de[5]_peakMeanRel',
#  'audSpec_Rfilt_sma[9]_qregc2',
#  'pcm_fftMag_spectralRollOff75.0_sma_quartile3',
#  'audSpec_Rfilt_sma[25]_lpc0',
#  'audSpec_Rfilt_sma_de[11]_peakDistStddev',
#  'jitterDDP_sma_lpc2',
#  'pcm_fftMag_spectralVariance_sma_de_iqr2-3',
#  'audSpec_Rfilt_sma[11]_iqr1-2',
#  'audSpec_Rfilt_sma_de[3]_upleveltime75',
#  'audSpec_Rfilt_sma_de[23]_meanSegLen',
#  'audSpec_Rfilt_sma[7]_iqr1-2',
#  'mfcc_sma[11]_skewness',
#  'mfcc_sma_de[7]_lpc1',
#  'audspecRasta_lengthL1norm_sma_de_iqr1-2',
#  'mfcc_sma_de[14]_minRangeRel',
#  'mfcc_sma_de[2]_peakMeanRel',
#  'audSpec_Rfilt_sma[7]_iqr2-3',
#  'pcm_fftMag_spectralHarmonicity_sma_de_peakMeanMeanDist',
#  'audSpec_Rfilt_sma_de[15]_peakDistStddev',
#  'audSpec_Rfilt_sma_de[2]_quartile3',
#  'pcm_fftMag_spectralEntropy_sma_lpc1',
#  'pcm_fftMag_spectralKurtosis_sma_risetime',
#  'audSpec_Rfilt_sma_de[7]_flatness',
#  'pcm_fftMag_spectralCentroid_sma_de_percentile1.0',
#  'audSpec_Rfilt_sma[16]_peakMeanAbs',
#  'audSpec_Rfilt_sma[21]_maxSegLen',
#  'F0final_sma_percentile1.0',
#  'F0final_sma_de_lpc4',
#  'pcm_fftMag_spectralRollOff75.0_sma_lpc0',
#  'audSpec_Rfilt_sma[6]_quartile3',
#  'audSpec_Rfilt_sma[18]_stddevFallingSlope',
#  'shimmerLocal_sma_percentile1.0',
#  'audSpec_Rfilt_sma[4]_maxPos',
#  'audSpec_Rfilt_sma_de[21]_peakDistStddev',
#  'audSpec_Rfilt_sma[22]_meanFallingSlope',
#  'pcm_fftMag_spectralRollOff75.0_sma_de_posamean',
#  'audSpec_Rfilt_sma_de[20]_iqr1-3',
#  'pcm_fftMag_spectralEntropy_sma_de_lpc1',
#  'mfcc_sma_de[9]_posamean',
#  'audSpec_Rfilt_sma_de[18]_flatness',
#  'audSpec_Rfilt_sma[10]_peakRangeAbs',
#  'mfcc_sma[4]_meanSegLen',
#  'mfcc_sma_de[4]_lpc4',
#  'mfcc_sma[12]_meanPeakDist',
#  'mfcc_sma[12]_meanRisingSlope',
#  'audSpec_Rfilt_sma[15]_linregc2',
#  'mfcc_sma_de[13]_peakMeanAbs',
#  'mfcc_sma_de[8]_skewness',
#  'audSpec_Rfilt_sma[25]_minPos',
#  'audSpec_Rfilt_sma[13]_iqr1-2',
#  'pcm_fftMag_spectralRollOff50.0_sma_stddev',
#  'audSpec_Rfilt_sma[17]_leftctime',
#  'mfcc_sma_de[2]_lpc1',
#  'audSpec_Rfilt_sma_de[19]_minPos',
#  'pcm_fftMag_spectralVariance_sma_de_lpc4',
#  'pcm_fftMag_spectralRollOff25.0_sma_maxPos',
#  'audSpec_Rfilt_sma[14]_quartile3',
#  'audSpec_Rfilt_sma_de[20]_lpc2',
#  'pcm_fftMag_spectralRollOff25.0_sma_iqr1-2',
#  'audSpec_Rfilt_sma_de[11]_upleveltime90',
#  'mfcc_sma[8]_maxPos',
#  'pcm_fftMag_spectralSkewness_sma_kurtosis',
#  'mfcc_sma_de[13]_quartile3',
#  'audSpec_Rfilt_sma[9]_centroid',
#  'F0final_sma_de_rqmean',
#  'audSpec_Rfilt_sma_de[5]_minRangeRel',
#  'audSpec_Rfilt_sma[18]_range',
#  'audSpec_Rfilt_sma[6]_maxPos',
#  'audSpec_Rfilt_sma[7]_flatness',
#  'audSpec_Rfilt_sma[11]_percentile99.0',
#  'mfcc_sma[6]_risetime',
#  'audSpec_Rfilt_sma[5]_flatness',
#  'mfcc_sma[4]_quartile1',
#  'audSpec_Rfilt_sma[7]_segLenStddev',
#  'mfcc_sma_de[1]_upleveltime50',
#  'audSpec_Rfilt_sma[19]_linregc2',
#  'pcm_fftMag_spectralHarmonicity_sma_peakDistStddev',
#  'audSpec_Rfilt_sma_de[7]_lpc0',
#  'jitterDDP_sma_skewness',
#  'pcm_fftMag_spectralHarmonicity_sma_de_lpc2',
#  'pcm_fftMag_fband250-650_sma_de_minRangeRel',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_iqr1-2',
#  'pcm_fftMag_spectralSlope_sma_peakMeanRel',
#  'audSpec_Rfilt_sma[21]_kurtosis',
#  'mfcc_sma_de[1]_pctlrange0-1',
#  'logHNR_sma_de_upleveltime50',
#  'mfcc_sma[3]_stddev',
#  'mfcc_sma[4]_kurtosis',
#  'mfcc_sma_de[5]_minPos',
#  'pcm_fftMag_spectralFlux_sma_de_upleveltime90',
#  'audSpec_Rfilt_sma_de[12]_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[1]_maxSegLen',
#  'pcm_fftMag_fband1000-4000_sma_de_peakMeanRel',
#  'mfcc_sma_de[8]_iqr1-3',
#  'audSpec_Rfilt_sma[10]_upleveltime50',
#  'audSpec_Rfilt_sma[10]_range',
#  'audSpec_Rfilt_sma[23]_meanRisingSlope',
#  'pcm_fftMag_spectralRollOff25.0_sma_peakMeanMeanDist',
#  'audSpec_Rfilt_sma[4]_meanFallingSlope',
#  'audSpec_Rfilt_sma[22]_peakRangeAbs',
#  'mfcc_sma_de[12]_minSegLen',
#  'pcm_fftMag_spectralEntropy_sma_iqr2-3',
#  'audSpec_Rfilt_sma[15]_peakMeanRel',
#  'audSpec_Rfilt_sma[15]_meanRisingSlope',
#  'mfcc_sma[2]_peakMeanAbs',
#  'mfcc_sma[8]_peakMeanRel',
#  'pcm_fftMag_spectralKurtosis_sma_linregerrQ',
#  'mfcc_sma[11]_stddev',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_lpc1',
#  'pcm_fftMag_spectralVariance_sma_de_peakMeanAbs',
#  'audSpec_Rfilt_sma_de[17]_minSegLen',
#  'mfcc_sma[8]_meanSegLen',
#  'audSpec_Rfilt_sma_de[15]_iqr1-2',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_peakRangeRel',
#  'audSpec_Rfilt_sma_de[17]_leftctime',
#  'pcm_fftMag_spectralRollOff50.0_sma_amean',
#  'audSpec_Rfilt_sma_de[15]_iqr1-3',
#  'pcm_fftMag_spectralRollOff50.0_sma_de_lpc3',
#  'audSpec_Rfilt_sma_de[9]_upleveltime50',
#  'audSpec_Rfilt_sma[0]_quartile2',
#  'audSpec_Rfilt_sma[15]_minRangeRel',
#  'audSpec_Rfilt_sma[1]_iqr1-3',
#  'mfcc_sma_de[11]_flatness',
#  'audSpec_Rfilt_sma[10]_upleveltime75',
#  'audSpec_Rfilt_sma[13]_percentile1.0',
#  'jitterLocal_sma_de_lpc1',
#  'audSpec_Rfilt_sma_de[21]_percentile1.0',
#  'pcm_fftMag_spectralSlope_sma_de_pctlrange0-1',
#  'mfcc_sma[11]_linregc1',
#  'audSpec_Rfilt_sma_de[15]_leftctime',
#  'audSpec_Rfilt_sma[4]_skewness',
#  'pcm_fftMag_spectralCentroid_sma_iqr1-2',
#  'mfcc_sma[10]_lpc1',
#  'pcm_fftMag_spectralRollOff90.0_sma_de_peakRangeAbs',
#  'audSpec_Rfilt_sma_de[21]_meanSegLen',
#  'audSpec_Rfilt_sma_de[6]_stddev',
#  'pcm_fftMag_spectralHarmonicity_sma_peakMeanMeanDist',
#  'mfcc_sma_de[14]_lpc1',
#  'mfcc_sma[14]_upleveltime75',
#  'pcm_fftMag_spectralSlope_sma_de_lpc1',
#  'F0final_sma_de_lpgain',
#  'audSpec_Rfilt_sma[0]_maxSegLen',
#  'pcm_fftMag_spectralEntropy_sma_de_flatness',
#  'audSpec_Rfilt_sma_de[6]_range',
#  'pcm_fftMag_spectralKurtosis_sma_iqr1-3',
#  'audSpec_Rfilt_sma[20]_peakMeanMeanDist',
#  'audSpec_Rfilt_sma[7]_qregc2',
#  'pcm_fftMag_spectralCentroid_sma_de_minPos',
#  'mfcc_sma_de[12]_lpgain',
#  'audSpec_Rfilt_sma[14]_upleveltime75',
#  'pcm_fftMag_spectralVariance_sma_stddevRisingSlope',
#  'mfcc_sma[14]_peakRangeRel',
#  'pcm_fftMag_spectralEntropy_sma_de_range',
#  'audSpec_Rfilt_sma[25]_iqr1-3',
#  'audSpec_Rfilt_sma_de[13]_lpc0',
#  'audSpec_Rfilt_sma_de[3]_minSegLen',
#  'pcm_fftMag_spectralCentroid_sma_lpc2',
#  'mfcc_sma_de[1]_meanSegLen',
#  'audSpec_Rfilt_sma[18]_linregc2',
#  'mfcc_sma[4]_qregc1',
#  'mfcc_sma_de[10]_quartile1',
#  'audSpec_Rfilt_sma_de[18]_segLenStddev',
#  'audSpec_Rfilt_sma[13]_iqr1-3',
#  'F0final_sma_de_quartile2',
#  'audSpec_Rfilt_sma_de[22]_minRangeRel',
#  'audSpec_Rfilt_sma_de[16]_pctlrange0-1',
#  'mfcc_sma[4]_qregerrQ',
#  'pcm_fftMag_spectralSlope_sma_upleveltime25',
#  'audSpec_Rfilt_sma_de[19]_quartile1',
#  'audSpec_Rfilt_sma[15]_pctlrange0-1',
#  'mfcc_sma_de[11]_upleveltime90',
#  'mfcc_sma_de[12]_iqr2-3',
#  'audSpec_Rfilt_sma[3]_segLenStddev',
#  'mfcc_sma_de[9]_kurtosis',
#  'audSpec_Rfilt_sma[25]_peakRangeAbs',
#  'audSpec_Rfilt_sma[12]_kurtosis',
#  'pcm_fftMag_spectralVariance_sma_maxPos',
#  'audSpec_Rfilt_sma_de[18]_upleveltime50',
#  'mfcc_sma[4]_peakDistStddev',
#  'pcm_fftMag_spectralRollOff90.0_sma_meanPeakDist',
#  'audSpec_Rfilt_sma[2]_kurtosis',
#  'shimmerLocal_sma_flatness',
#  'pcm_fftMag_fband250-650_sma_rqmean',
#  'pcm_fftMag_spectralHarmonicity_sma_lpc4',
#  'audSpec_Rfilt_sma[18]_peakRangeAbs',
#  'mfcc_sma[10]_kurtosis',
#  'mfcc_sma[11]_range',
#  'pcm_zcr_sma_de_maxSegLen',
#  'audSpec_Rfilt_sma_de[11]_percentile99.0',
#  'audSpec_Rfilt_sma[24]_stddevRisingSlope',
#  'audSpec_Rfilt_sma[5]_meanRisingSlope',
#  'mfcc_sma_de[1]_maxSegLen',
#  'audSpec_Rfilt_sma_de[19]_rqmean',
#  'F0final_sma_lpc2',
#  'pcm_zcr_sma_centroid',
#  'pcm_fftMag_spectralKurtosis_sma_percentile1.0',
#  'audSpec_Rfilt_sma[24]_linregc2',
#  'audSpec_Rfilt_sma_de[20]_stddevFallingSlope',
#  'jitterLocal_sma_iqr1-2',
#  'audSpec_Rfilt_sma[24]_peakRangeAbs',
#  'audSpec_Rfilt_sma[25]_flatness',
#  'mfcc_sma[6]_maxSegLen',
#  ...}
# --------------------------------------------------

# %% [markdown]
# ---
